# %% [markdown]
# ### `---------------Mandatory Information to fill------------`

# %% [markdown]
# ### Group ID:
# ### Group Members Name with Student ID:
# 1. Student 1
# 2. Student 2
# 3. Student 3
# 4. Student 4

# %% [markdown]
# `-------------------Write your remarks (if any) that you want should get consider at the time of evaluation---------------`

# %% [markdown]
# Remarks: ##Add here

# %% [markdown]
# # Background
#
# In the world of online streaming, user satisfaction and engagement are critical metrics for the success of a movie recommendation system. A well-designed recommendation algorithm can significantly enhance user experience by suggesting movies that align with their preferences, leading to higher platform retention and usage. Recommendation systems face the challenge of balancing exploration (discovering new movies) with exploitation (recommending known favourites) to maximize user satisfaction over time.

# %% [markdown]
# # Scenario
#
# Imagine a leading online movie streaming platform, TrendMovie Inc., that aims to become the go-to destination for personalized movie recommendations. The platform features a vast collection of movies catering to diverse audiences. TrendMovie Inc. wants to optimize its recommendation strategy to deliver maximum user satisfaction while maintaining a high level of engagement. Each movie recommendation is treated as an interaction with the user, and their feedback is used to refine the recommendation strategy dynamically.

# %% [markdown]
# # Objective
#
# Your objective is to design and implement a recommendation system using Multi-Armed Bandit (MAB) algorithms to maximize cumulative user satisfaction. The system should dynamically allocate recommendations by learning user preferences in real-time, striking the right balance between exploration and exploitation.

# %% [markdown]
# # Dataset
#
# The dataset contains user ratings for a variety of movies. Key columns in the dataset include:
# *   **User ID:** A unique identifier for each user.
# *   **Movie ID:** A unique identifier for each.
# *   **Rating:** A score provided by the user for a movie (on a scale of 1 to 5).
# *   **Timestamp:** The time when the rating was given (optional for this assignment).
#
# ***Link for accessing dataset:***
# https://drive.google.com/file/d/1gfobhqlVCw8Oo52JCiYpEBGhG5k7cWBr/view?usp=drive_link

# %% [markdown]
# # Environment Details
#
# **Arms:** Each movie represents an "arm" in the MAB framework. The probability of a movie being liked by a user is initially unknown and will be estimated based on user feedback during the interactions.
# For example:
#
# Arm 1: Movie A
#
# Arm 2: Movie B
#
# Arm 3: Movie C
#
# ... and so on, for all movies in the dataset.
#
# **Reward Function:**
# The reward function is defined based on user ratings:
#
# ***Reward = 1:*** The user rates the movie high star (e.g., 4 or 5 stars).
#
# ***Reward = 0:*** The user rates the movie low star (e.g., 1, 2, or 3 stars).
#
#
# **Assumptions:**
#
# Run simulations for 1000 iterations for each policy

# %% [markdown]
# # Requirements and Deliverables:
# Implement the Multi-Arm Bandit Problem for the given above scenario for all the below mentioned policy methods.

# %% [markdown]
# ### Initialize constants

# %%
# !pip install gym pandas
# Out:
# Requirement already satisfied: gym in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (0.26.2)
# Requirement already satisfied: pandas in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.18.0 in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (from gym) (2.2.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (from gym) (3.1.0)
# Requirement already satisfied: gym_notices>=0.0.4 in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (from gym) (0.0.8)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/jawahar/Documents/bitsMTech/sem2/drl/playground/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import random
import numpy as np
import pandas as pd
import gym

# Constants
no_of_iterations = 1000

# Initialize value function and policy

# %% [markdown]
# # Load Dataset (0.5M)

# %%
# Code for Dataset loading and print dataset statistics
#-----write your code below this line---------


# Data Exploration

import pandas as pd

# Load the dataset
dataset = pd.read_csv("TrendMovie.csv")

# Display basic information about the dataset
print("Dataset Info:")
dataset.info()

print("Total Movie count:")
print(len(dataset['movieId'].unique()))

# Display the first few rows of the dataset
print("\nDataset Preview:")
print(dataset.head())

# Check for missing values
print("\nMissing Values:")
print(dataset.isnull().sum())

# Summary statistics of the ratings
print("\nSummary Statistics:")
print(dataset["rating"].describe())

# Preprocessing

# Convert timestamp to a readable format
dataset["timestamp"] = pd.to_datetime(dataset["timestamp"], unit="s")

# Sort by user and timestamp for consistent processing
dataset = dataset.sort_values(by=["userId", "timestamp"]).reset_index(drop=True)

print("\nProcessed Dataset Preview:")
print(dataset.head())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100836 non-null  int64
#  1   movieId    100836 non-null  int64
#  2   rating     100836 non-null  float64
#  3   timestamp  100836 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB
# Total Movie count:
# 9724
#
# Dataset Preview:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#
# Missing Values:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# dtype: int64
#
# Summary Statistics:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: rating, dtype: float64
#
# Processed Dataset Preview:
#    userId  movieId  rating           timestamp
# 0       1      804     4.0 2000-07-30 18:08:19
# 1       1     1210     5.0 2000-07-30 18:08:19
# 2       1     2018     5.0 2000-07-30 18:08:43
# 3       1     2628     4.0 2000-07-30 18:08:43
# 4       1     2826     4.0 2000-07-30 18:08:43

# %% [markdown]
# # Design a Movie Environment (0.5M)

# %%
import random
import pandas as pd
import gym
import math

# Define the Movie Recommendation Environment
class MovieRecommendationEnv(gym.Env):
    def __init__(self, data):
        """
        Initialize the environment.

        Parameters:
        - data: DataFrame containing user ratings with columns: 'userId', 'movieId', 'rating'.
        """
        self.data = data
        self.movies = data['movieId'].unique()  # Unique movie IDs
        self.state = {movie_id: [] for movie_id in self.movies}  # Tracks user feedback for each movie
        self.reset()  # Initialize the state

    def step(self, action):
        """
        Simulate a user's interaction with a selected movie (arm).

        Parameters:
        - action: The selected movie ID (arm).

        Returns:
        - state: Updated state with rewards for each movie.
        - reward: 1 if liked, 0 otherwise.
        - done: Always False, as this is a continuous environment.
        - debug: None for now (can be extended for additional info).
        """
        # Filter ratings for the selected movie
        movie_ratings = self.data[self.data['movieId'] == action]['rating']
        
        # Use the average rating for the movie
        if not movie_ratings.empty:
            # print(action, 'avg ', movie_ratings.sum(), len(movie_ratings), movie_ratings.mean())
            avg_rating = movie_ratings.mean()
            # avg_rating = movie_ratings.sample().iloc[0]
            reward = 1 if avg_rating >= 4.0 else 0  # High rating gives a reward of 1
        else:
            reward = 0  # Default to 0 if no ratings are available

        self.state[action].append(reward)  # Update state with reward
        done = False
        debug = None
        return self.state, reward, done, debug

    def reset(self):
        """
        Reset the environment state. Each movie starts with an empty feedback list.

        Returns:
        - state: The initial state of the environment.
        """
        self.state = {movie_id: [] for movie_id in self.movies}
        return self.state

    def render(self, mode="ascii"):
        """
        Display statistics of user feedback for all movies.

        Parameters:
        - mode: The rendering mode (default is "ascii").
        """
        returns = {movie_id: sum(rewards) for movie_id, rewards in self.state.items()}
        trials = {movie_id: len(rewards) for movie_id, rewards in self.state.items()}
        print(f'===== Total Trials: {sum(trials.values())} =====')
        for movie_id, total_return in returns.items():
            total_trials = trials[movie_id]
            print(f'Movie {movie_id} | Returns: {total_return}, Trials: {total_trials}')
        print(f'===== Total Returns: {sum(returns.values())} =====')

# Greedy Policy Implementation
def greedy_policy(env, iterations=1000):
    """
    Implement the greedy policy to select movies based on estimated probabilities.

    Parameters:
    - env: The movie recommendation environment.
    - iterations: Number of iterations for the simulation.

    Returns:
    - None
    """
    estimated_values = {movie_id: 0 for movie_id in env.movies}  # Initialize estimated values
    counts = {movie_id: 0 for movie_id in env.movies}  # Track the number of times each movie is selected

    for _ in range(iterations):
        # Select the movie with the highest estimated probability (greedy choice)
        action = max(estimated_values, key=estimated_values.get)

        # Interact with the environment using the selected action
        _, reward, _, _ = env.step(action)

        # Update counts and estimated values
        counts[action] += 1
        estimated_values[action] += (reward - estimated_values[action]) / counts[action]

    # Render final statistics
    env.render()

# Random Policy Implementation
def random_policy(env, iterations=1000):
    """
    Implement the random policy to select movies randomly.

    Parameters:
    - env: The movie recommendation environment.
    - iterations: Number of iterations for the simulation.

    Returns:
    - None
    """
    for _ in range(iterations):
        # Select a random movie
        action = random.choice(env.movies)
        
        print('selected', action)

        # Interact with the environment using the selected action
        _, reward, _, _ = env.step(action)

    # Render final statistics
    env.render()

# Upper Confidence Bound (UCB) Policy Implementation
def ucb_policy(env, iterations=1000, c=2):
    """
    Implement the UCB policy to select movies based on estimated values and confidence bounds.

    Parameters:
    - env: The movie recommendation environment.
    - iterations: Number of iterations for the simulation.
    - c: Exploration parameter for UCB.

    Returns:
    - None
    """
    estimated_values = {movie_id: 0 for movie_id in env.movies}  # Initialize estimated values
    counts = {movie_id: 0 for movie_id in env.movies}  # Track the number of times each movie is selected

    for t in range(1, iterations + 1):
        # Select the movie based on UCB formula
        ucb_values = {}
        for movie_id in env.movies:
            if counts[movie_id] == 0:
                ucb_values[movie_id] = float('inf')  # Select untried movies first
            else:
                ucb_values[movie_id] = estimated_values[movie_id] + c * math.sqrt(math.log(t) / counts[movie_id])

        action = max(ucb_values, key=ucb_values.get)

        # Interact with the environment using the selected action
        _, reward, _, _ = env.step(action)

        # Update counts and estimated values
        counts[action] += 1
        estimated_values[action] += (reward - estimated_values[action]) / counts[action]

    # Render final statistics
    env.render()

# Main Execution
if __name__ == "__main__":
    # Load the dataset
    csv_file_path = "TrendMovie.csv"  # Path to the CSV file
    data = pd.read_csv(csv_file_path)  # Load data from the CSV

    # Initialize the environment with the dataset
    env = MovieRecommendationEnv(data)

    # Run the policies
    print("\nRunning Random Policy:")
    random_policy(env)
    
    # print("Running Greedy Policy:")
    # greedy_policy(env)


    # print("\nRunning UCB Policy:")
    # ucb_policy(env)
# Out:
# Running Random Policy:
# selected 250
# selected 4454
# selected 48596
# selected 1936
# selected 132422
# selected 8952
# selected 1083
# selected 1214
# selected 130842
# selected 2789
# selected 44204
# selected 80363
# selected 77800
# selected 2559
# selected 32116
# selected 68522
# selected 6962
# selected 142456
# selected 3567
# selected 988
# selected 91094
# selected 182715
# selected 2951
# selected 1230
# selected 3357
# selected 1078
# selected 2549
# selected 88235
# selected 4957
# selected 7354
# selected 1371
# selected 57843
# selected 98243
# selected 278
# selected 31878
# selected 6620
# selected 99191
# selected 133419
# selected 5028
# selected 2669
# selected 58025
# selected 4757
# selected 30825
# selected 6100
# selected 51088
# selected 8934
# selected 110669
# selected 5941
# selected 6551
# selected 71282
# selected 2648
# selected 84246
# selected 4439
# selected 131013
# selected 6218
# selected 1446
# selected 2657
# selected 65682
# selected 100487
# selected 125
# selected 8601
# selected 67734
# selected 50800
# selected 8959
# selected 180263
# selected 7991
# selected 74696
# selected 122246
# selected 59725
# selected 54997
# selected 85261
# selected 8270
# selected 5637
# selected 5480
# selected 4256
# selected 52279
# selected 148632
# selected 8183
# selected 41014
# selected 55205
# selected 25996
# selected 91128
# selected 67997
# selected 99636
# selected 1627
# selected 37384
# selected 1248
# selected 8848
# selected 71268
# selected 62394
# selected 33683
# selected 1392
# selected 5244
# selected 58998
# selected 5112
# selected 2857
# selected 1249
# selected 1906
# selected 113350
# selected 100226
# selected 50356
# selected 109941
# selected 5159
# selected 1613
# selected 6571
# selected 6752
# selected 2351
# selected 110586
# selected 775
# selected 6773
# selected 95149
# selected 4653
# selected 129250
# selected 354
# selected 7299
# selected 899
# selected 3731
# selected 133802
# selected 7487
# selected 222
# selected 50740
# selected 8118
# selected 385
# selected 1957
# selected 113849
# selected 2502
# selected 424
# selected 125916
# selected 111622
# selected 92420
# selected 168418
# selected 26350
# selected 43917
# selected 41769
# selected 33564
# selected 136469
# selected 3544
# selected 4022
# selected 54908
# selected 97328
# selected 4029
# selected 62376
# selected 385
# selected 65188
# selected 55577
# selected 3832
# selected 4149
# selected 5069
# selected 95149
# selected 137218
# selected 733
# selected 98239
# selected 8370
# selected 6323
# selected 5308
# selected 134184
# selected 3060
# selected 147376
# selected 102684
# selected 61394
# selected 88140
# selected 106540
# selected 1095
# selected 7987
# selected 49824
# selected 313
# selected 70361
# selected 3037
# selected 2796
# selected 117849
# selected 388
# selected 8363
# selected 1011
# selected 4814
# selected 563
# selected 2625
# selected 5853
# selected 8633
# selected 4688
# selected 34072
# selected 1295
# selected 1938
# selected 405
# selected 1236
# selected 5515
# selected 2706
# selected 92665
# selected 92243
# selected 4147
# selected 34534
# selected 54190
# selected 7075
# selected 5909
# selected 95873
# selected 116505
# selected 4381
# selected 127319
# selected 7285
# selected 3910
# selected 549
# selected 61692
# selected 4437
# selected 1731
# selected 45666
# selected 60647
# selected 136359
# selected 123545
# selected 110127
# selected 2539
# selected 102749
# selected 5944
# selected 7581
# selected 4390
# selected 5416
# selected 4141
# selected 745
# selected 45969
# selected 161918
# selected 134326
# selected 92509
# selected 107999
# selected 1950
# selected 6283
# selected 900
# selected 2348
# selected 133645
# selected 3042
# selected 3004
# selected 37729
# selected 6713
# selected 310
# selected 2893
# selected 95473
# selected 1331
# selected 114126
# selected 759
# selected 1081
# selected 171
# selected 91485
# selected 6542
# selected 2332
# selected 72921
# selected 4641
# selected 49276
# selected 79428
# selected 127390
# selected 94
# selected 134041
# selected 173925
# selected 5041
# selected 59615
# selected 8771
# selected 5527
# selected 4267
# selected 147410
# selected 174403
# selected 32632
# selected 1332
# selected 2810
# selected 5780
# selected 120919
# selected 48032
# selected 998
# selected 4263
# selected 2805
# selected 5358
# selected 61255
# selected 7713
# selected 1785
# selected 181413
# selected 61262
# selected 93040
# selected 60389
# selected 326
# selected 3046
# selected 4014
# selected 43376
# selected 96488
# selected 6286
# selected 5742
# selected 103335
# selected 127172
# selected 61248
# selected 3516
# selected 94325
# selected 3067
# selected 5498
# selected 61350
# selected 8199
# selected 922
# selected 1653
# selected 544
# selected 179813
# selected 4725
# selected 6461
# selected 7082
# selected 6935
# selected 2738
# selected 5361
# selected 5047
# selected 57522
# selected 540
# selected 32743
# selected 1213
# selected 72720
# selected 109846
# selected 4973
# selected 86
# selected 7092
# selected 8190
# selected 415
# selected 107348
# selected 177765
# selected 618
# selected 96430
# selected 849
# selected 2802
# selected 27820
# selected 4565
# selected 8261
# selected 152270
# selected 722
# selected 94122
# selected 5538
# selected 1024
# selected 106144
# selected 58297
# selected 5477
# selected 4429
# selected 160730
# selected 26131
# selected 6588
# selected 238
# selected 8915
# selected 3733
# selected 5802
# selected 3984
# selected 55553
# selected 2765
# selected 4104
# selected 3043
# selected 6950
# selected 7063
# selected 1114
# selected 2357
# selected 96655
# selected 54190
# selected 56715
# selected 2731
# selected 6412
# selected 27105
# selected 2462
# selected 69844
# selected 2906
# selected 5840
# selected 8410
# selected 5951
# selected 76030
# selected 117109
# selected 71550
# selected 7811
# selected 4711
# selected 26700
# selected 66203
# selected 97921
# selected 5915
# selected 70728
# selected 6217
# selected 1263
# selected 448
# selected 140541
# selected 1355
# selected 55854
# selected 125
# selected 5187
# selected 176423
# selected 4971
# selected 85397
# selected 5021
# selected 2363
# selected 121035
# selected 86880
# selected 1973
# selected 138798
# selected 82202
# selected 6665
# selected 168492
# selected 4915
# selected 66198
# selected 7109
# selected 7988
# selected 2362
# selected 141830
# selected 3649
# selected 8864
# selected 74282
# selected 173925
# selected 4954
# selected 108188
# selected 32582
# selected 4475
# selected 4756
# selected 2459
# selected 3535
# selected 579
# selected 959
# selected 2935
# selected 63276
# selected 1189
# selected 5028
# selected 5962
# selected 82854
# selected 1498
# selected 426
# selected 3395
# selected 92422
# selected 93982
# selected 33148
# selected 602
# selected 27266
# selected 2754
# selected 8798
# selected 3040
# selected 69304
# selected 47124
# selected 61
# selected 7669
# selected 7657
# selected 5621
# selected 1887
# selected 5054
# selected 80219
# selected 86377
# selected 2231
# selected 64983
# selected 3000
# selected 4371
# selected 73822
# selected 109850
# selected 4313
# selected 5672
# selected 8225
# selected 5170
# selected 84847
# selected 7030
# selected 165347
# selected 104644
# selected 105468
# selected 1329
# selected 81564
# selected 66783
# selected 5912
# selected 7720
# selected 151559
# selected 6159
# selected 1007
# selected 48262
# selected 2792
# selected 8977
# selected 106
# selected 4602
# selected 7395
# selected 3567
# selected 8506
# selected 365
# selected 69860
# selected 7756
# selected 1794
# selected 70521
# selected 3844
# selected 7987
# selected 2739
# selected 1391
# selected 4466
# selected 5239
# selected 3044
# selected 162344
# selected 26903
# selected 7728
# selected 52885
# selected 26854
# selected 5875
# selected 2615
# selected 4234
# selected 3267
# selected 5630
# selected 1931
# selected 1328
# selected 34
# selected 8131
# selected 1010
# selected 4686
# selected 4708
# selected 1502
# selected 36850
# selected 1825
# selected 80166
# selected 159403
# selected 1960
# selected 52462
# selected 645
# selected 5680
# selected 4381
# selected 6
# selected 95690
# selected 1542
# selected 3087
# selected 5293
# selected 2323
# selected 113453
# selected 7084
# selected 32666
# selected 59995
# selected 5991
# selected 175
# selected 85213
# selected 6316
# selected 608
# selected 1440
# selected 6691
# selected 3283
# selected 25782
# selected 70361
# selected 26539
# selected 3313
# selected 126921
# selected 7165
# selected 93320
# selected 57499
# selected 77414
# selected 31
# selected 182297
# selected 3694
# selected 8665
# selected 2613
# selected 4754
# selected 471
# selected 932
# selected 151739
# selected 168326
# selected 4630
# selected 948
# selected 70663
# selected 134847
# selected 26350
# selected 128838
# selected 96114
# selected 7265
# selected 1620
# selected 3183
# selected 39516
# selected 39414
# selected 4599
# selected 1373
# selected 2350
# selected 7024
# selected 95449
# selected 89745
# selected 79946
# selected 1066
# selected 6688
# selected 4641
# selected 2967
# selected 7767
# selected 56782
# selected 5059
# selected 2985
# selected 94985
# selected 73290
# selected 5515
# selected 81512
# selected 275
# selected 8385
# selected 2306
# selected 88785
# selected 169992
# selected 5883
# selected 62376
# selected 1671
# selected 83910
# selected 3998
# selected 3966
# selected 83480
# selected 1382
# selected 2719
# selected 94867
# selected 118888
# selected 181139
# selected 56152
# selected 68159
# selected 45501
# selected 4381
# selected 7089
# selected 7362
# selected 48214
# selected 132362
# selected 2134
# selected 6541
# selected 2149
# selected 106
# selected 8665
# selected 3289
# selected 231
# selected 60408
# selected 94
# selected 61210
# selected 96737
# selected 7449
# selected 4849
# selected 109596
# selected 8154
# selected 25905
# selected 141820
# selected 5621
# selected 178061
# selected 7059
# selected 5219
# selected 5347
# selected 51412
# selected 2300
# selected 1103
# selected 63062
# selected 201
# selected 4252
# selected 124484
# selected 78088
# selected 5189
# selected 8633
# selected 2054
# selected 7727
# selected 32914
# selected 7321
# selected 896
# selected 5968
# selected 102802
# selected 7052
# selected 2946
# selected 81949
# selected 162600
# selected 176423
# selected 4809
# selected 26158
# selected 563
# selected 60832
# selected 6002
# selected 6242
# selected 4502
# selected 136359
# selected 8363
# selected 5387
# selected 3299
# selected 4313
# selected 34532
# selected 5095
# selected 140711
# selected 33164
# selected 8958
# selected 27830
# selected 1584
# selected 674
# selected 160646
# selected 134109
# selected 3767
# selected 4429
# selected 1323
# selected 106648
# selected 5341
# selected 8518
# selected 4593
# selected 5105
# selected 2692
# selected 142509
# selected 3760
# selected 8815
# selected 3007
# selected 203
# selected 42946
# selected 7037
# selected 193573
# selected 140711
# selected 151479
# selected 2116
# selected 62718
# selected 183197
# selected 99117
# selected 152284
# selected 139157
# selected 39516
# selected 90576
# selected 113278
# selected 162
# selected 53138
# selected 4477
# selected 52975
# selected 1844
# selected 32511
# selected 3897
# selected 2506
# selected 3684
# selected 8015
# selected 59915
# selected 5628
# selected 55207
# selected 2659
# selected 1964
# selected 4267
# selected 2950
# selected 736
# selected 2346
# selected 8045
# selected 2297
# selected 1385
# selected 8491
# selected 6385
# selected 1332
# selected 90890
# selected 83910
# selected 26344
# selected 150596
# selected 8989
# selected 262
# selected 4251
# selected 3787
# selected 3249
# selected 52241
# selected 107
# selected 7811
# selected 590
# selected 479
# selected 3035
# selected 8364
# selected 71530
# selected 5409
# selected 151687
# selected 46865
# selected 1608
# selected 1928
# selected 7017
# selected 3609
# selected 71453
# selected 145150
# selected 1859
# selected 55232
# selected 89586
# selected 95307
# selected 1688
# selected 1610
# selected 5265
# selected 4898
# selected 179401
# selected 285
# selected 4995
# selected 173
# selected 1221
# selected 1739
# selected 838
# selected 800
# selected 178129
# selected 1993
# selected 217
# selected 4578
# selected 75416
# selected 7831
# selected 6723
# selected 4235
# selected 3834
# selected 4889
# selected 1377
# selected 71129
# selected 2406
# selected 129779
# selected 1983
# selected 96150
# selected 96691
# selected 2396
# selected 97701
# selected 146662
# selected 5574
# selected 95558
# selected 160730
# selected 56782
# selected 2983
# selected 7443
# selected 68205
# selected 8199
# selected 72011
# selected 1230
# selected 2528
# selected 196
# selected 841
# selected 2153
# selected 1965
# selected 456
# selected 8605
# selected 159858
# selected 2906
# selected 5684
# selected 6344
# selected 176415
# selected 105197
# selected 32584
# selected 4304
# selected 26812
# selected 7090
# selected 173873
# selected 7993
# selected 53447
# selected 2001
# selected 131104
# selected 1156
# selected 26712
# selected 136341
# selected 4827
# selected 3046
# selected 4840
# selected 71248
# selected 59131
# selected 1310
# selected 64575
# selected 3835
# selected 26612
# selected 6985
# selected 6547
# selected 74946
# selected 6310
# selected 2268
# selected 1116
# selected 173255
# selected 61986
# selected 4129
# selected 3814
# selected 851
# selected 127202
# selected 287
# selected 5569
# selected 241
# selected 5010
# selected 7317
# selected 1967
# selected 55820
# selected 14
# selected 766
# selected 709
# selected 3002
# selected 91981
# selected 3076
# selected 3999
# selected 1527
# selected 26308
# selected 1888
# selected 26765
# selected 4574
# selected 164367
# selected 5580
# selected 533
# selected 8831
# selected 3863
# selected 158402
# selected 303
# selected 7951
# selected 2577
# selected 7093
# selected 6155
# selected 5584
# selected 171251
# selected 27155
# selected 4325
# selected 5128
# selected 1342
# selected 25841
# selected 2799
# selected 626
# selected 50794
# selected 26726
# selected 69278
# selected 27692
# selected 27373
# selected 3315
# selected 89386
# selected 83374
# selected 6187
# selected 85020
# selected 5120
# selected 30812
# selected 4725
# selected 104076
# selected 2623
# selected 45728
# selected 471
# selected 225
# selected 104337
# selected 69685
# selected 25947
# selected 5879
# selected 63479
# selected 33164
# selected 7163
# selected 52579
# selected 3676
# selected 2496
# selected 70687
# selected 6368
# selected 1650
# selected 2376
# selected 3021
# selected 53125
# selected 26840
# selected 3737
# selected 4672
# selected 4743
# selected 2820
# selected 2081
# selected 1537
# selected 4228
# selected 3201
# selected 152063
# selected 53138
# selected 8057
# selected 135777
# selected 74228
# selected 4795
# selected 55391
# selected 678
# selected 30810
# selected 26394
# selected 5707
# selected 8772
# selected 5063
# selected 135436
# selected 4275
# selected 27537
# selected 55020
# selected 102066
# selected 53000
# selected 947
# selected 3994
# selected 4015
# selected 30994
# selected 8730
# selected 1652
# selected 65126
# selected 84942
# selected 7376
# selected 89190
# selected 183635
# selected 8912
# selected 5114
# selected 27604
# selected 113378
# selected 3677
# selected 185135
# selected 80748
# selected 99007
# selected 3767
# selected 87834
# selected 6125
# selected 41716
# selected 60289
# selected 27846
# selected 6100
# selected 4613
# selected 26391
# selected 5591
# selected 5139
# selected 27773
# selected 64969
# selected 3498
# selected 8014
# selected 1275
# selected 2023
# selected 7987
# selected 75416
# selected 67087
# selected 48412
# selected 7015
# selected 174681
# selected 41828
# selected 32554
# selected 136840
# selected 8643
# selected 6195
# selected 3362
# selected 7375
# selected 5135
# selected 27595
# selected 312
# selected 5266
# selected 26394
# selected 51709
# selected 6979
# selected 139157
# selected 91266
# selected 1227
# selected 62376
# selected 54997
# selected 127108
# selected 167538
# selected 122906
# selected 5438
# selected 514
# ===== Total Trials: 1000 =====
# Movie 1 | Returns: 0, Trials: 0
# Movie 3 | Returns: 0, Trials: 0
# Movie 6 | Returns: 0, Trials: 1
# Movie 47 | Returns: 0, Trials: 0
# Movie 50 | Returns: 0, Trials: 0
# Movie 70 | Returns: 0, Trials: 0
# Movie 101 | Returns: 0, Trials: 0
# Movie 110 | Returns: 0, Trials: 0
# Movie 151 | Returns: 0, Trials: 0
# Movie 157 | Returns: 0, Trials: 0
# Movie 163 | Returns: 0, Trials: 0
# Movie 216 | Returns: 0, Trials: 0
# Movie 223 | Returns: 0, Trials: 0
# Movie 231 | Returns: 0, Trials: 1
# Movie 235 | Returns: 0, Trials: 0
# Movie 260 | Returns: 0, Trials: 0
# Movie 296 | Returns: 0, Trials: 0
# Movie 316 | Returns: 0, Trials: 0
# Movie 333 | Returns: 0, Trials: 0
# Movie 349 | Returns: 0, Trials: 0
# Movie 356 | Returns: 0, Trials: 0
# Movie 362 | Returns: 0, Trials: 0
# Movie 367 | Returns: 0, Trials: 0
# Movie 423 | Returns: 0, Trials: 0
# Movie 441 | Returns: 0, Trials: 0
# Movie 457 | Returns: 0, Trials: 0
# Movie 480 | Returns: 0, Trials: 0
# Movie 500 | Returns: 0, Trials: 0
# Movie 527 | Returns: 0, Trials: 0
# Movie 543 | Returns: 0, Trials: 0
# Movie 552 | Returns: 0, Trials: 0
# Movie 553 | Returns: 0, Trials: 0
# Movie 590 | Returns: 0, Trials: 1
# Movie 592 | Returns: 0, Trials: 0
# Movie 593 | Returns: 0, Trials: 0
# Movie 596 | Returns: 0, Trials: 0
# Movie 608 | Returns: 1, Trials: 1
# Movie 648 | Returns: 0, Trials: 0
# Movie 661 | Returns: 0, Trials: 0
# Movie 673 | Returns: 0, Trials: 0
# Movie 733 | Returns: 0, Trials: 1
# Movie 736 | Returns: 0, Trials: 1
# Movie 780 | Returns: 0, Trials: 0
# Movie 804 | Returns: 0, Trials: 0
# Movie 919 | Returns: 0, Trials: 0
# Movie 923 | Returns: 0, Trials: 0
# Movie 940 | Returns: 0, Trials: 0
# Movie 943 | Returns: 0, Trials: 0
# Movie 954 | Returns: 0, Trials: 0
# Movie 1009 | Returns: 0, Trials: 0
# Movie 1023 | Returns: 0, Trials: 0
# Movie 1024 | Returns: 0, Trials: 1
# Movie 1025 | Returns: 0, Trials: 0
# Movie 1029 | Returns: 0, Trials: 0
# Movie 1030 | Returns: 0, Trials: 0
# Movie 1031 | Returns: 0, Trials: 0
# Movie 1032 | Returns: 0, Trials: 0
# Movie 1042 | Returns: 0, Trials: 0
# Movie 1049 | Returns: 0, Trials: 0
# Movie 1060 | Returns: 0, Trials: 0
# Movie 1073 | Returns: 0, Trials: 0
# Movie 1080 | Returns: 0, Trials: 0
# Movie 1089 | Returns: 0, Trials: 0
# Movie 1090 | Returns: 0, Trials: 0
# Movie 1092 | Returns: 0, Trials: 0
# Movie 1097 | Returns: 0, Trials: 0
# Movie 1127 | Returns: 0, Trials: 0
# Movie 1136 | Returns: 0, Trials: 0
# Movie 1196 | Returns: 0, Trials: 0
# Movie 1197 | Returns: 0, Trials: 0
# Movie 1198 | Returns: 0, Trials: 0
# Movie 1206 | Returns: 0, Trials: 0
# Movie 1208 | Returns: 0, Trials: 0
# Movie 1210 | Returns: 0, Trials: 0
# Movie 1213 | Returns: 1, Trials: 1
# Movie 1214 | Returns: 0, Trials: 1
# Movie 1219 | Returns: 0, Trials: 0
# Movie 1220 | Returns: 0, Trials: 0
# Movie 1222 | Returns: 0, Trials: 0
# Movie 1224 | Returns: 0, Trials: 0
# Movie 1226 | Returns: 0, Trials: 0
# Movie 1240 | Returns: 0, Trials: 0
# Movie 1256 | Returns: 0, Trials: 0
# Movie 1258 | Returns: 0, Trials: 0
# Movie 1265 | Returns: 0, Trials: 0
# Movie 1270 | Returns: 0, Trials: 0
# Movie 1275 | Returns: 0, Trials: 1
# Movie 1278 | Returns: 0, Trials: 0
# Movie 1282 | Returns: 0, Trials: 0
# Movie 1291 | Returns: 0, Trials: 0
# Movie 1298 | Returns: 0, Trials: 0
# Movie 1348 | Returns: 0, Trials: 0
# Movie 1377 | Returns: 0, Trials: 1
# Movie 1396 | Returns: 0, Trials: 0
# Movie 1408 | Returns: 0, Trials: 0
# Movie 1445 | Returns: 0, Trials: 0
# Movie 1473 | Returns: 0, Trials: 0
# Movie 1500 | Returns: 0, Trials: 0
# Movie 1517 | Returns: 0, Trials: 0
# Movie 1552 | Returns: 0, Trials: 0
# Movie 1573 | Returns: 0, Trials: 0
# Movie 1580 | Returns: 0, Trials: 0
# Movie 1587 | Returns: 0, Trials: 0
# Movie 1617 | Returns: 0, Trials: 0
# Movie 1620 | Returns: 0, Trials: 1
# Movie 1625 | Returns: 0, Trials: 0
# Movie 1644 | Returns: 0, Trials: 0
# Movie 1676 | Returns: 0, Trials: 0
# Movie 1732 | Returns: 0, Trials: 0
# Movie 1777 | Returns: 0, Trials: 0
# Movie 1793 | Returns: 0, Trials: 0
# Movie 1804 | Returns: 0, Trials: 0
# Movie 1805 | Returns: 0, Trials: 0
# Movie 1920 | Returns: 0, Trials: 0
# Movie 1927 | Returns: 0, Trials: 0
# Movie 1954 | Returns: 0, Trials: 0
# Movie 1967 | Returns: 0, Trials: 1
# Movie 2000 | Returns: 0, Trials: 0
# Movie 2005 | Returns: 0, Trials: 0
# Movie 2012 | Returns: 0, Trials: 0
# Movie 2018 | Returns: 0, Trials: 0
# Movie 2028 | Returns: 0, Trials: 0
# Movie 2033 | Returns: 0, Trials: 0
# Movie 2046 | Returns: 0, Trials: 0
# Movie 2048 | Returns: 0, Trials: 0
# Movie 2054 | Returns: 0, Trials: 1
# Movie 2058 | Returns: 0, Trials: 0
# Movie 2078 | Returns: 0, Trials: 0
# Movie 2090 | Returns: 0, Trials: 0
# Movie 2093 | Returns: 0, Trials: 0
# Movie 2094 | Returns: 0, Trials: 0
# Movie 2096 | Returns: 0, Trials: 0
# Movie 2099 | Returns: 0, Trials: 0
# Movie 2105 | Returns: 0, Trials: 0
# Movie 2115 | Returns: 0, Trials: 0
# Movie 2116 | Returns: 0, Trials: 1
# Movie 2137 | Returns: 0, Trials: 0
# Movie 2139 | Returns: 0, Trials: 0
# Movie 2141 | Returns: 0, Trials: 0
# Movie 2143 | Returns: 0, Trials: 0
# Movie 2161 | Returns: 0, Trials: 0
# Movie 2174 | Returns: 0, Trials: 0
# Movie 2193 | Returns: 0, Trials: 0
# Movie 2253 | Returns: 0, Trials: 0
# Movie 2268 | Returns: 0, Trials: 1
# Movie 2273 | Returns: 0, Trials: 0
# Movie 2291 | Returns: 0, Trials: 0
# Movie 2329 | Returns: 0, Trials: 0
# Movie 2338 | Returns: 0, Trials: 0
# Movie 2353 | Returns: 0, Trials: 0
# Movie 2366 | Returns: 0, Trials: 0
# Movie 2387 | Returns: 0, Trials: 0
# Movie 2389 | Returns: 0, Trials: 0
# Movie 2395 | Returns: 0, Trials: 0
# Movie 2406 | Returns: 0, Trials: 1
# Movie 2414 | Returns: 0, Trials: 0
# Movie 2427 | Returns: 0, Trials: 0
# Movie 2450 | Returns: 0, Trials: 0
# Movie 2459 | Returns: 0, Trials: 1
# Movie 2470 | Returns: 0, Trials: 0
# Movie 2478 | Returns: 0, Trials: 0
# Movie 2492 | Returns: 0, Trials: 0
# Movie 2502 | Returns: 1, Trials: 1
# Movie 2528 | Returns: 0, Trials: 1
# Movie 2529 | Returns: 0, Trials: 0
# Movie 2542 | Returns: 0, Trials: 0
# Movie 2571 | Returns: 0, Trials: 0
# Movie 2580 | Returns: 0, Trials: 0
# Movie 2596 | Returns: 0, Trials: 0
# Movie 2616 | Returns: 0, Trials: 0
# Movie 2617 | Returns: 0, Trials: 0
# Movie 2628 | Returns: 0, Trials: 0
# Movie 2640 | Returns: 0, Trials: 0
# Movie 2641 | Returns: 0, Trials: 0
# Movie 2644 | Returns: 0, Trials: 0
# Movie 2648 | Returns: 0, Trials: 1
# Movie 2654 | Returns: 0, Trials: 0
# Movie 2657 | Returns: 0, Trials: 1
# Movie 2692 | Returns: 1, Trials: 1
# Movie 2700 | Returns: 0, Trials: 0
# Movie 2716 | Returns: 0, Trials: 0
# Movie 2761 | Returns: 0, Trials: 0
# Movie 2797 | Returns: 0, Trials: 0
# Movie 2826 | Returns: 0, Trials: 0
# Movie 2858 | Returns: 0, Trials: 0
# Movie 2872 | Returns: 0, Trials: 0
# Movie 2899 | Returns: 0, Trials: 0
# Movie 2916 | Returns: 0, Trials: 0
# Movie 2944 | Returns: 0, Trials: 0
# Movie 2947 | Returns: 0, Trials: 0
# Movie 2948 | Returns: 0, Trials: 0
# Movie 2949 | Returns: 0, Trials: 0
# Movie 2959 | Returns: 0, Trials: 0
# Movie 2985 | Returns: 0, Trials: 1
# Movie 2987 | Returns: 0, Trials: 0
# Movie 2991 | Returns: 0, Trials: 0
# Movie 2993 | Returns: 0, Trials: 0
# Movie 2997 | Returns: 0, Trials: 0
# Movie 3033 | Returns: 0, Trials: 0
# Movie 3034 | Returns: 0, Trials: 0
# Movie 3052 | Returns: 0, Trials: 0
# Movie 3053 | Returns: 0, Trials: 0
# Movie 3062 | Returns: 0, Trials: 0
# Movie 3147 | Returns: 0, Trials: 0
# Movie 3168 | Returns: 0, Trials: 0
# Movie 3176 | Returns: 0, Trials: 0
# Movie 3243 | Returns: 0, Trials: 0
# Movie 3247 | Returns: 0, Trials: 0
# Movie 3253 | Returns: 0, Trials: 0
# Movie 3273 | Returns: 0, Trials: 0
# Movie 3386 | Returns: 0, Trials: 0
# Movie 3439 | Returns: 0, Trials: 0
# Movie 3440 | Returns: 0, Trials: 0
# Movie 3441 | Returns: 0, Trials: 0
# Movie 3448 | Returns: 0, Trials: 0
# Movie 3450 | Returns: 0, Trials: 0
# Movie 3479 | Returns: 0, Trials: 0
# Movie 3489 | Returns: 0, Trials: 0
# Movie 3527 | Returns: 0, Trials: 0
# Movie 3578 | Returns: 0, Trials: 0
# Movie 3617 | Returns: 0, Trials: 0
# Movie 3639 | Returns: 0, Trials: 0
# Movie 3671 | Returns: 0, Trials: 0
# Movie 3702 | Returns: 0, Trials: 0
# Movie 3703 | Returns: 0, Trials: 0
# Movie 3729 | Returns: 0, Trials: 0
# Movie 3740 | Returns: 0, Trials: 0
# Movie 3744 | Returns: 0, Trials: 0
# Movie 3793 | Returns: 0, Trials: 0
# Movie 3809 | Returns: 0, Trials: 0
# Movie 4006 | Returns: 0, Trials: 0
# Movie 5060 | Returns: 0, Trials: 0
# Movie 318 | Returns: 0, Trials: 0
# Movie 1704 | Returns: 0, Trials: 0
# Movie 6874 | Returns: 0, Trials: 0
# Movie 8798 | Returns: 0, Trials: 1
# Movie 46970 | Returns: 0, Trials: 0
# Movie 48516 | Returns: 0, Trials: 0
# Movie 58559 | Returns: 0, Trials: 0
# Movie 60756 | Returns: 0, Trials: 0
# Movie 68157 | Returns: 0, Trials: 0
# Movie 71535 | Returns: 0, Trials: 0
# Movie 74458 | Returns: 0, Trials: 0
# Movie 77455 | Returns: 0, Trials: 0
# Movie 79132 | Returns: 0, Trials: 0
# Movie 80489 | Returns: 0, Trials: 0
# Movie 80906 | Returns: 0, Trials: 0
# Movie 86345 | Returns: 0, Trials: 0
# Movie 89774 | Returns: 0, Trials: 0
# Movie 91529 | Returns: 0, Trials: 0
# Movie 91658 | Returns: 0, Trials: 0
# Movie 99114 | Returns: 0, Trials: 0
# Movie 106782 | Returns: 0, Trials: 0
# Movie 109487 | Returns: 0, Trials: 0
# Movie 112552 | Returns: 0, Trials: 0
# Movie 114060 | Returns: 0, Trials: 0
# Movie 115713 | Returns: 0, Trials: 0
# Movie 122882 | Returns: 0, Trials: 0
# Movie 131724 | Returns: 0, Trials: 0
# Movie 31 | Returns: 0, Trials: 1
# Movie 647 | Returns: 0, Trials: 0
# Movie 688 | Returns: 0, Trials: 0
# Movie 720 | Returns: 0, Trials: 0
# Movie 849 | Returns: 0, Trials: 1
# Movie 914 | Returns: 0, Trials: 0
# Movie 1093 | Returns: 0, Trials: 0
# Movie 1124 | Returns: 0, Trials: 0
# Movie 1263 | Returns: 0, Trials: 1
# Movie 1272 | Returns: 0, Trials: 0
# Movie 1302 | Returns: 0, Trials: 0
# Movie 1371 | Returns: 0, Trials: 1
# Movie 2080 | Returns: 0, Trials: 0
# Movie 2288 | Returns: 0, Trials: 0
# Movie 2424 | Returns: 0, Trials: 0
# Movie 2851 | Returns: 0, Trials: 0
# Movie 3024 | Returns: 0, Trials: 0
# Movie 3210 | Returns: 0, Trials: 0
# Movie 3949 | Returns: 0, Trials: 0
# Movie 4518 | Returns: 0, Trials: 0
# Movie 5048 | Returns: 0, Trials: 0
# Movie 5181 | Returns: 0, Trials: 0
# Movie 5746 | Returns: 0, Trials: 0
# Movie 5764 | Returns: 0, Trials: 0
# Movie 5919 | Returns: 0, Trials: 0
# Movie 6238 | Returns: 0, Trials: 0
# Movie 6835 | Returns: 0, Trials: 0
# Movie 7899 | Returns: 0, Trials: 0
# Movie 7991 | Returns: 0, Trials: 1
# Movie 26409 | Returns: 0, Trials: 0
# Movie 70946 | Returns: 0, Trials: 0
# Movie 72378 | Returns: 0, Trials: 0
# Movie 21 | Returns: 0, Trials: 0
# Movie 32 | Returns: 0, Trials: 0
# Movie 45 | Returns: 0, Trials: 0
# Movie 52 | Returns: 0, Trials: 0
# Movie 58 | Returns: 0, Trials: 0
# Movie 106 | Returns: 2, Trials: 2
# Movie 125 | Returns: 0, Trials: 2
# Movie 126 | Returns: 0, Trials: 0
# Movie 162 | Returns: 1, Trials: 1
# Movie 171 | Returns: 0, Trials: 1
# Movie 176 | Returns: 0, Trials: 0
# Movie 190 | Returns: 0, Trials: 0
# Movie 215 | Returns: 0, Trials: 0
# Movie 222 | Returns: 0, Trials: 1
# Movie 232 | Returns: 0, Trials: 0
# Movie 247 | Returns: 0, Trials: 0
# Movie 265 | Returns: 0, Trials: 0
# Movie 319 | Returns: 0, Trials: 0
# Movie 342 | Returns: 0, Trials: 0
# Movie 345 | Returns: 0, Trials: 0
# Movie 348 | Returns: 0, Trials: 0
# Movie 351 | Returns: 0, Trials: 0
# Movie 357 | Returns: 0, Trials: 0
# Movie 368 | Returns: 0, Trials: 0
# Movie 417 | Returns: 0, Trials: 0
# Movie 450 | Returns: 0, Trials: 0
# Movie 475 | Returns: 0, Trials: 0
# Movie 492 | Returns: 0, Trials: 0
# Movie 509 | Returns: 0, Trials: 0
# Movie 538 | Returns: 0, Trials: 0
# Movie 539 | Returns: 0, Trials: 0
# Movie 588 | Returns: 0, Trials: 0
# Movie 595 | Returns: 0, Trials: 0
# Movie 599 | Returns: 0, Trials: 0
# Movie 708 | Returns: 0, Trials: 0
# Movie 759 | Returns: 0, Trials: 1
# Movie 800 | Returns: 1, Trials: 1
# Movie 892 | Returns: 0, Trials: 0
# Movie 898 | Returns: 0, Trials: 0
# Movie 899 | Returns: 1, Trials: 1
# Movie 902 | Returns: 0, Trials: 0
# Movie 904 | Returns: 0, Trials: 0
# Movie 908 | Returns: 0, Trials: 0
# Movie 910 | Returns: 0, Trials: 0
# Movie 912 | Returns: 0, Trials: 0
# Movie 920 | Returns: 0, Trials: 0
# Movie 930 | Returns: 0, Trials: 0
# Movie 937 | Returns: 0, Trials: 0
# Movie 1046 | Returns: 0, Trials: 0
# Movie 1057 | Returns: 0, Trials: 0
# Movie 1077 | Returns: 0, Trials: 0
# Movie 1079 | Returns: 0, Trials: 0
# Movie 1084 | Returns: 0, Trials: 0
# Movie 1086 | Returns: 0, Trials: 0
# Movie 1094 | Returns: 0, Trials: 0
# Movie 1103 | Returns: 1, Trials: 1
# Movie 1179 | Returns: 0, Trials: 0
# Movie 1183 | Returns: 0, Trials: 0
# Movie 1188 | Returns: 0, Trials: 0
# Movie 1199 | Returns: 0, Trials: 0
# Movie 1203 | Returns: 0, Trials: 0
# Movie 1211 | Returns: 0, Trials: 0
# Movie 1225 | Returns: 0, Trials: 0
# Movie 1250 | Returns: 0, Trials: 0
# Movie 1259 | Returns: 0, Trials: 0
# Movie 1266 | Returns: 0, Trials: 0
# Movie 1279 | Returns: 0, Trials: 0
# Movie 1283 | Returns: 0, Trials: 0
# Movie 1288 | Returns: 0, Trials: 0
# Movie 1304 | Returns: 0, Trials: 0
# Movie 1391 | Returns: 0, Trials: 1
# Movie 1449 | Returns: 0, Trials: 0
# Movie 1466 | Returns: 0, Trials: 0
# Movie 1597 | Returns: 0, Trials: 0
# Movie 1641 | Returns: 0, Trials: 0
# Movie 1719 | Returns: 0, Trials: 0
# Movie 1733 | Returns: 0, Trials: 0
# Movie 1734 | Returns: 0, Trials: 0
# Movie 1834 | Returns: 0, Trials: 0
# Movie 1860 | Returns: 0, Trials: 0
# Movie 1883 | Returns: 0, Trials: 0
# Movie 1885 | Returns: 0, Trials: 0
# Movie 1892 | Returns: 0, Trials: 0
# Movie 1895 | Returns: 0, Trials: 0
# Movie 1907 | Returns: 0, Trials: 0
# Movie 1914 | Returns: 0, Trials: 0
# Movie 1916 | Returns: 0, Trials: 0
# Movie 1923 | Returns: 0, Trials: 0
# Movie 1947 | Returns: 0, Trials: 0
# Movie 1966 | Returns: 0, Trials: 0
# Movie 1968 | Returns: 0, Trials: 0
# Movie 2019 | Returns: 0, Trials: 0
# Movie 2076 | Returns: 0, Trials: 0
# Movie 2109 | Returns: 0, Trials: 0
# Movie 2145 | Returns: 0, Trials: 0
# Movie 2150 | Returns: 0, Trials: 0
# Movie 2186 | Returns: 0, Trials: 0
# Movie 2203 | Returns: 0, Trials: 0
# Movie 2204 | Returns: 0, Trials: 0
# Movie 2282 | Returns: 0, Trials: 0
# Movie 2324 | Returns: 0, Trials: 0
# Movie 2336 | Returns: 0, Trials: 0
# Movie 2351 | Returns: 1, Trials: 1
# Movie 2359 | Returns: 0, Trials: 0
# Movie 2390 | Returns: 0, Trials: 0
# Movie 2467 | Returns: 0, Trials: 0
# Movie 2583 | Returns: 0, Trials: 0
# Movie 2599 | Returns: 0, Trials: 0
# Movie 2683 | Returns: 0, Trials: 0
# Movie 2712 | Returns: 0, Trials: 0
# Movie 2762 | Returns: 0, Trials: 0
# Movie 2763 | Returns: 0, Trials: 0
# Movie 2770 | Returns: 0, Trials: 0
# Movie 2791 | Returns: 0, Trials: 0
# Movie 2843 | Returns: 0, Trials: 0
# Movie 2874 | Returns: 0, Trials: 0
# Movie 2921 | Returns: 0, Trials: 0
# Movie 2926 | Returns: 0, Trials: 0
# Movie 2973 | Returns: 0, Trials: 0
# Movie 3044 | Returns: 0, Trials: 1
# Movie 3060 | Returns: 0, Trials: 1
# Movie 3079 | Returns: 0, Trials: 0
# Movie 3083 | Returns: 0, Trials: 0
# Movie 3160 | Returns: 0, Trials: 0
# Movie 3175 | Returns: 0, Trials: 0
# Movie 3204 | Returns: 0, Trials: 0
# Movie 3255 | Returns: 0, Trials: 0
# Movie 3317 | Returns: 0, Trials: 0
# Movie 3358 | Returns: 0, Trials: 0
# Movie 3365 | Returns: 0, Trials: 0
# Movie 3408 | Returns: 0, Trials: 0
# Movie 3481 | Returns: 0, Trials: 0
# Movie 3508 | Returns: 0, Trials: 0
# Movie 3538 | Returns: 0, Trials: 0
# Movie 3591 | Returns: 0, Trials: 0
# Movie 3788 | Returns: 0, Trials: 0
# Movie 3851 | Returns: 0, Trials: 0
# Movie 3897 | Returns: 0, Trials: 1
# Movie 3911 | Returns: 0, Trials: 0
# Movie 3967 | Returns: 0, Trials: 0
# Movie 3996 | Returns: 0, Trials: 0
# Movie 4002 | Returns: 0, Trials: 0
# Movie 4014 | Returns: 0, Trials: 1
# Movie 4020 | Returns: 0, Trials: 0
# Movie 4021 | Returns: 0, Trials: 0
# Movie 4027 | Returns: 0, Trials: 0
# Movie 4029 | Returns: 0, Trials: 1
# Movie 4033 | Returns: 0, Trials: 0
# Movie 4034 | Returns: 0, Trials: 0
# Movie 4074 | Returns: 0, Trials: 0
# Movie 4121 | Returns: 0, Trials: 0
# Movie 4144 | Returns: 0, Trials: 0
# Movie 4166 | Returns: 0, Trials: 0
# Movie 4226 | Returns: 0, Trials: 0
# Movie 4239 | Returns: 0, Trials: 0
# Movie 4246 | Returns: 0, Trials: 0
# Movie 4252 | Returns: 0, Trials: 1
# Movie 4260 | Returns: 0, Trials: 0
# Movie 4273 | Returns: 0, Trials: 0
# Movie 4308 | Returns: 0, Trials: 0
# Movie 4347 | Returns: 0, Trials: 0
# Movie 4381 | Returns: 0, Trials: 3
# Movie 4641 | Returns: 0, Trials: 2
# Movie 4741 | Returns: 0, Trials: 0
# Movie 4765 | Returns: 0, Trials: 0
# Movie 4881 | Returns: 0, Trials: 0
# Movie 4896 | Returns: 0, Trials: 0
# Movie 4902 | Returns: 0, Trials: 0
# Movie 4967 | Returns: 0, Trials: 0
# Movie 34 | Returns: 0, Trials: 1
# Movie 36 | Returns: 0, Trials: 0
# Movie 39 | Returns: 0, Trials: 0
# Movie 150 | Returns: 0, Trials: 0
# Movie 153 | Returns: 0, Trials: 0
# Movie 253 | Returns: 0, Trials: 0
# Movie 261 | Returns: 0, Trials: 0
# Movie 266 | Returns: 0, Trials: 0
# Movie 290 | Returns: 0, Trials: 0
# Movie 300 | Returns: 0, Trials: 0
# Movie 344 | Returns: 0, Trials: 0
# Movie 364 | Returns: 0, Trials: 0
# Movie 380 | Returns: 0, Trials: 0
# Movie 410 | Returns: 0, Trials: 0
# Movie 474 | Returns: 0, Trials: 0
# Movie 515 | Returns: 0, Trials: 0
# Movie 531 | Returns: 0, Trials: 0
# Movie 534 | Returns: 0, Trials: 0
# Movie 589 | Returns: 0, Trials: 0
# Movie 594 | Returns: 0, Trials: 0
# Movie 597 | Returns: 0, Trials: 0
# Movie 2 | Returns: 0, Trials: 0
# Movie 4 | Returns: 0, Trials: 0
# Movie 5 | Returns: 0, Trials: 0
# Movie 7 | Returns: 0, Trials: 0
# Movie 8 | Returns: 0, Trials: 0
# Movie 10 | Returns: 0, Trials: 0
# Movie 11 | Returns: 0, Trials: 0
# Movie 13 | Returns: 0, Trials: 0
# Movie 15 | Returns: 0, Trials: 0
# Movie 16 | Returns: 0, Trials: 0
# Movie 17 | Returns: 0, Trials: 0
# Movie 19 | Returns: 0, Trials: 0
# Movie 22 | Returns: 0, Trials: 0
# Movie 24 | Returns: 0, Trials: 0
# Movie 25 | Returns: 0, Trials: 0
# Movie 26 | Returns: 0, Trials: 0
# Movie 27 | Returns: 0, Trials: 0
# Movie 41 | Returns: 0, Trials: 0
# Movie 43 | Returns: 0, Trials: 0
# Movie 46 | Returns: 0, Trials: 0
# Movie 54 | Returns: 0, Trials: 0
# Movie 60 | Returns: 0, Trials: 0
# Movie 61 | Returns: 0, Trials: 1
# Movie 62 | Returns: 0, Trials: 0
# Movie 65 | Returns: 0, Trials: 0
# Movie 66 | Returns: 0, Trials: 0
# Movie 76 | Returns: 0, Trials: 0
# Movie 79 | Returns: 0, Trials: 0
# Movie 86 | Returns: 0, Trials: 1
# Movie 87 | Returns: 0, Trials: 0
# Movie 88 | Returns: 0, Trials: 0
# Movie 89 | Returns: 0, Trials: 0
# Movie 92 | Returns: 0, Trials: 0
# Movie 93 | Returns: 0, Trials: 0
# Movie 95 | Returns: 0, Trials: 0
# Movie 100 | Returns: 0, Trials: 0
# Movie 102 | Returns: 0, Trials: 0
# Movie 104 | Returns: 0, Trials: 0
# Movie 105 | Returns: 0, Trials: 0
# Movie 112 | Returns: 0, Trials: 0
# Movie 113 | Returns: 0, Trials: 0
# Movie 135 | Returns: 0, Trials: 0
# Movie 140 | Returns: 0, Trials: 0
# Movie 141 | Returns: 0, Trials: 0
# Movie 145 | Returns: 0, Trials: 0
# Movie 146 | Returns: 0, Trials: 0
# Movie 158 | Returns: 0, Trials: 0
# Movie 159 | Returns: 0, Trials: 0
# Movie 160 | Returns: 0, Trials: 0
# Movie 161 | Returns: 0, Trials: 0
# Movie 165 | Returns: 0, Trials: 0
# Movie 168 | Returns: 0, Trials: 0
# Movie 170 | Returns: 0, Trials: 0
# Movie 174 | Returns: 0, Trials: 0
# Movie 177 | Returns: 0, Trials: 0
# Movie 179 | Returns: 0, Trials: 0
# Movie 180 | Returns: 0, Trials: 0
# Movie 181 | Returns: 0, Trials: 0
# Movie 185 | Returns: 0, Trials: 0
# Movie 186 | Returns: 0, Trials: 0
# Movie 189 | Returns: 0, Trials: 0
# Movie 191 | Returns: 0, Trials: 0
# Movie 195 | Returns: 0, Trials: 0
# Movie 196 | Returns: 0, Trials: 1
# Movie 201 | Returns: 0, Trials: 1
# Movie 204 | Returns: 0, Trials: 0
# Movie 205 | Returns: 0, Trials: 0
# Movie 207 | Returns: 0, Trials: 0
# Movie 208 | Returns: 0, Trials: 0
# Movie 209 | Returns: 0, Trials: 0
# Movie 210 | Returns: 0, Trials: 0
# Movie 212 | Returns: 0, Trials: 0
# Movie 217 | Returns: 0, Trials: 1
# Movie 218 | Returns: 0, Trials: 0
# Movie 219 | Returns: 0, Trials: 0
# Movie 224 | Returns: 0, Trials: 0
# Movie 225 | Returns: 0, Trials: 1
# Movie 230 | Returns: 0, Trials: 0
# Movie 234 | Returns: 0, Trials: 0
# Movie 236 | Returns: 0, Trials: 0
# Movie 237 | Returns: 0, Trials: 0
# Movie 239 | Returns: 0, Trials: 0
# Movie 240 | Returns: 0, Trials: 0
# Movie 243 | Returns: 0, Trials: 0
# Movie 248 | Returns: 0, Trials: 0
# Movie 250 | Returns: 0, Trials: 1
# Movie 251 | Returns: 0, Trials: 0
# Movie 252 | Returns: 0, Trials: 0
# Movie 254 | Returns: 0, Trials: 0
# Movie 256 | Returns: 0, Trials: 0
# Movie 257 | Returns: 0, Trials: 0
# Movie 258 | Returns: 0, Trials: 0
# Movie 262 | Returns: 0, Trials: 1
# Movie 267 | Returns: 0, Trials: 0
# Movie 270 | Returns: 0, Trials: 0
# Movie 271 | Returns: 0, Trials: 0
# Movie 273 | Returns: 0, Trials: 0
# Movie 274 | Returns: 0, Trials: 0
# Movie 276 | Returns: 0, Trials: 0
# Movie 277 | Returns: 0, Trials: 0
# Movie 279 | Returns: 0, Trials: 0
# Movie 281 | Returns: 0, Trials: 0
# Movie 282 | Returns: 0, Trials: 0
# Movie 288 | Returns: 0, Trials: 0
# Movie 289 | Returns: 0, Trials: 0
# Movie 291 | Returns: 0, Trials: 0
# Movie 292 | Returns: 0, Trials: 0
# Movie 293 | Returns: 0, Trials: 0
# Movie 302 | Returns: 0, Trials: 0
# Movie 303 | Returns: 0, Trials: 1
# Movie 304 | Returns: 0, Trials: 0
# Movie 310 | Returns: 0, Trials: 1
# Movie 312 | Returns: 0, Trials: 1
# Movie 313 | Returns: 0, Trials: 1
# Movie 314 | Returns: 0, Trials: 0
# Movie 315 | Returns: 0, Trials: 0
# Movie 317 | Returns: 0, Trials: 0
# Movie 327 | Returns: 0, Trials: 0
# Movie 329 | Returns: 0, Trials: 0
# Movie 330 | Returns: 0, Trials: 0
# Movie 332 | Returns: 0, Trials: 0
# Movie 336 | Returns: 0, Trials: 0
# Movie 337 | Returns: 0, Trials: 0
# Movie 339 | Returns: 0, Trials: 0
# Movie 340 | Returns: 0, Trials: 0
# Movie 343 | Returns: 0, Trials: 0
# Movie 347 | Returns: 0, Trials: 0
# Movie 350 | Returns: 0, Trials: 0
# Movie 352 | Returns: 0, Trials: 0
# Movie 353 | Returns: 0, Trials: 0
# Movie 354 | Returns: 0, Trials: 1
# Movie 355 | Returns: 0, Trials: 0
# Movie 358 | Returns: 0, Trials: 0
# Movie 359 | Returns: 0, Trials: 0
# Movie 360 | Returns: 0, Trials: 0
# Movie 361 | Returns: 0, Trials: 0
# Movie 366 | Returns: 0, Trials: 0
# Movie 370 | Returns: 0, Trials: 0
# Movie 371 | Returns: 0, Trials: 0
# Movie 374 | Returns: 0, Trials: 0
# Movie 377 | Returns: 0, Trials: 0
# Movie 378 | Returns: 0, Trials: 0
# Movie 381 | Returns: 0, Trials: 0
# Movie 382 | Returns: 0, Trials: 0
# Movie 383 | Returns: 0, Trials: 0
# Movie 405 | Returns: 0, Trials: 1
# Movie 412 | Returns: 0, Trials: 0
# Movie 415 | Returns: 0, Trials: 1
# Movie 416 | Returns: 0, Trials: 0
# Movie 419 | Returns: 0, Trials: 0
# Movie 426 | Returns: 0, Trials: 1
# Movie 432 | Returns: 0, Trials: 0
# Movie 434 | Returns: 0, Trials: 0
# Movie 435 | Returns: 0, Trials: 0
# Movie 437 | Returns: 0, Trials: 0
# Movie 440 | Returns: 0, Trials: 0
# Movie 445 | Returns: 0, Trials: 0
# Movie 454 | Returns: 0, Trials: 0
# Movie 455 | Returns: 0, Trials: 0
# Movie 458 | Returns: 0, Trials: 0
# Movie 460 | Returns: 0, Trials: 0
# Movie 466 | Returns: 0, Trials: 0
# Movie 468 | Returns: 0, Trials: 0
# Movie 469 | Returns: 0, Trials: 0
# Movie 472 | Returns: 0, Trials: 0
# Movie 477 | Returns: 0, Trials: 0
# Movie 485 | Returns: 0, Trials: 0
# Movie 489 | Returns: 0, Trials: 0
# Movie 490 | Returns: 0, Trials: 0
# Movie 491 | Returns: 0, Trials: 0
# Movie 493 | Returns: 0, Trials: 0
# Movie 494 | Returns: 0, Trials: 0
# Movie 497 | Returns: 0, Trials: 0
# Movie 502 | Returns: 0, Trials: 0
# Movie 505 | Returns: 0, Trials: 0
# Movie 508 | Returns: 0, Trials: 0
# Movie 510 | Returns: 0, Trials: 0
# Movie 516 | Returns: 0, Trials: 0
# Movie 520 | Returns: 0, Trials: 0
# Movie 524 | Returns: 0, Trials: 0
# Movie 532 | Returns: 0, Trials: 0
# Movie 536 | Returns: 0, Trials: 0
# Movie 537 | Returns: 0, Trials: 0
# Movie 540 | Returns: 0, Trials: 1
# Movie 542 | Returns: 0, Trials: 0
# Movie 546 | Returns: 0, Trials: 0
# Movie 548 | Returns: 0, Trials: 0
# Movie 569 | Returns: 0, Trials: 0
# Movie 575 | Returns: 0, Trials: 0
# Movie 587 | Returns: 0, Trials: 0
# Movie 606 | Returns: 0, Trials: 0
# Movie 609 | Returns: 0, Trials: 0
# Movie 616 | Returns: 0, Trials: 0
# Movie 628 | Returns: 0, Trials: 0
# Movie 631 | Returns: 0, Trials: 0
# Movie 637 | Returns: 0, Trials: 0
# Movie 640 | Returns: 0, Trials: 0
# Movie 662 | Returns: 0, Trials: 0
# Movie 667 | Returns: 0, Trials: 0
# Movie 694 | Returns: 0, Trials: 0
# Movie 697 | Returns: 0, Trials: 0
# Movie 700 | Returns: 0, Trials: 0
# Movie 704 | Returns: 0, Trials: 0
# Movie 709 | Returns: 0, Trials: 1
# Movie 710 | Returns: 0, Trials: 0
# Movie 711 | Returns: 0, Trials: 0
# Movie 719 | Returns: 0, Trials: 0
# Movie 747 | Returns: 0, Trials: 0
# Movie 762 | Returns: 0, Trials: 0
# Movie 765 | Returns: 0, Trials: 0
# Movie 775 | Returns: 0, Trials: 1
# Movie 783 | Returns: 0, Trials: 0
# Movie 795 | Returns: 0, Trials: 0
# Movie 799 | Returns: 0, Trials: 0
# Movie 801 | Returns: 0, Trials: 0
# Movie 802 | Returns: 0, Trials: 0
# Movie 818 | Returns: 0, Trials: 0
# Movie 830 | Returns: 0, Trials: 0
# Movie 835 | Returns: 0, Trials: 0
# Movie 837 | Returns: 0, Trials: 0
# Movie 838 | Returns: 0, Trials: 1
# Movie 839 | Returns: 0, Trials: 0
# Movie 842 | Returns: 0, Trials: 0
# Movie 848 | Returns: 0, Trials: 0
# Movie 852 | Returns: 0, Trials: 0
# Movie 867 | Returns: 0, Trials: 0
# Movie 880 | Returns: 0, Trials: 0
# Movie 881 | Returns: 0, Trials: 0
# Movie 888 | Returns: 0, Trials: 0
# Movie 891 | Returns: 0, Trials: 0
# Movie 979 | Returns: 0, Trials: 0
# Movie 981 | Returns: 0, Trials: 0
# Movie 986 | Returns: 0, Trials: 0
# Movie 991 | Returns: 0, Trials: 0
# Movie 996 | Returns: 0, Trials: 0
# Movie 999 | Returns: 0, Trials: 0
# Movie 1004 | Returns: 0, Trials: 0
# Movie 1006 | Returns: 0, Trials: 0
# Movie 1061 | Returns: 0, Trials: 0
# Movie 1064 | Returns: 0, Trials: 0
# Movie 1082 | Returns: 0, Trials: 0
# Movie 750 | Returns: 0, Trials: 0
# Movie 924 | Returns: 0, Trials: 0
# Movie 1101 | Returns: 0, Trials: 0
# Movie 1246 | Returns: 0, Trials: 0
# Movie 1584 | Returns: 0, Trials: 1
# Movie 1610 | Returns: 0, Trials: 1
# Movie 1682 | Returns: 0, Trials: 0
# Movie 1784 | Returns: 0, Trials: 0
# Movie 1917 | Returns: 0, Trials: 0
# Movie 2671 | Returns: 0, Trials: 0
# Movie 2688 | Returns: 0, Trials: 0
# Movie 2701 | Returns: 0, Trials: 0
# Movie 2717 | Returns: 0, Trials: 0
# Movie 3114 | Returns: 0, Trials: 0
# Movie 3354 | Returns: 0, Trials: 0
# Movie 3623 | Returns: 0, Trials: 0
# Movie 3869 | Returns: 0, Trials: 0
# Movie 3916 | Returns: 0, Trials: 0
# Movie 3977 | Returns: 0, Trials: 0
# Movie 3994 | Returns: 0, Trials: 1
# Movie 4018 | Returns: 0, Trials: 0
# Movie 4223 | Returns: 0, Trials: 0
# Movie 4306 | Returns: 0, Trials: 0
# Movie 4310 | Returns: 0, Trials: 0
# Movie 4370 | Returns: 0, Trials: 0
# Movie 4643 | Returns: 0, Trials: 0
# Movie 4700 | Returns: 0, Trials: 0
# Movie 4844 | Returns: 0, Trials: 0
# Movie 4874 | Returns: 0, Trials: 0
# Movie 4886 | Returns: 0, Trials: 0
# Movie 4963 | Returns: 0, Trials: 0
# Movie 4993 | Returns: 0, Trials: 0
# Movie 4995 | Returns: 1, Trials: 1
# Movie 5218 | Returns: 0, Trials: 0
# Movie 5349 | Returns: 0, Trials: 0
# Movie 5378 | Returns: 0, Trials: 0
# Movie 5445 | Returns: 0, Trials: 0
# Movie 5459 | Returns: 0, Trials: 0
# Movie 5464 | Returns: 0, Trials: 0
# Movie 5502 | Returns: 0, Trials: 0
# Movie 5618 | Returns: 0, Trials: 0
# Movie 5816 | Returns: 0, Trials: 0
# Movie 5952 | Returns: 0, Trials: 0
# Movie 5989 | Returns: 0, Trials: 0
# Movie 5991 | Returns: 0, Trials: 1
# Movie 6333 | Returns: 0, Trials: 0
# Movie 6365 | Returns: 0, Trials: 0
# Movie 6534 | Returns: 0, Trials: 0
# Movie 6539 | Returns: 0, Trials: 0
# Movie 6863 | Returns: 0, Trials: 0
# Movie 6934 | Returns: 0, Trials: 0
# Movie 7143 | Returns: 0, Trials: 0
# Movie 7153 | Returns: 0, Trials: 0
# Movie 7155 | Returns: 0, Trials: 0
# Movie 7445 | Returns: 0, Trials: 0
# Movie 8207 | Returns: 0, Trials: 0
# Movie 8360 | Returns: 0, Trials: 0
# Movie 8368 | Returns: 0, Trials: 0
# Movie 8373 | Returns: 0, Trials: 0
# Movie 8528 | Returns: 0, Trials: 0
# Movie 8636 | Returns: 0, Trials: 0
# Movie 8665 | Returns: 0, Trials: 2
# Movie 8666 | Returns: 0, Trials: 0
# Movie 8783 | Returns: 0, Trials: 0
# Movie 8808 | Returns: 0, Trials: 0
# Movie 8865 | Returns: 0, Trials: 0
# Movie 8870 | Returns: 0, Trials: 0
# Movie 8907 | Returns: 0, Trials: 0
# Movie 8908 | Returns: 0, Trials: 0
# Movie 8949 | Returns: 0, Trials: 0
# Movie 8957 | Returns: 0, Trials: 0
# Movie 8958 | Returns: 0, Trials: 1
# Movie 8961 | Returns: 0, Trials: 0
# Movie 8965 | Returns: 0, Trials: 0
# Movie 8970 | Returns: 0, Trials: 0
# Movie 8972 | Returns: 0, Trials: 0
# Movie 8984 | Returns: 0, Trials: 0
# Movie 27741 | Returns: 0, Trials: 0
# Movie 30812 | Returns: 0, Trials: 1
# Movie 30816 | Returns: 0, Trials: 0
# Movie 31878 | Returns: 0, Trials: 1
# Movie 32029 | Returns: 0, Trials: 0
# Movie 32031 | Returns: 0, Trials: 0
# Movie 32296 | Returns: 0, Trials: 0
# Movie 32587 | Returns: 0, Trials: 0
# Movie 33162 | Returns: 0, Trials: 0
# Movie 33493 | Returns: 0, Trials: 0
# Movie 33794 | Returns: 0, Trials: 0
# Movie 33836 | Returns: 0, Trials: 0
# Movie 34048 | Returns: 0, Trials: 0
# Movie 34319 | Returns: 0, Trials: 0
# Movie 37741 | Returns: 0, Trials: 0
# Movie 38388 | Returns: 0, Trials: 0
# Movie 42002 | Returns: 0, Trials: 0
# Movie 45499 | Returns: 0, Trials: 0
# Movie 45517 | Returns: 0, Trials: 0
# Movie 45668 | Returns: 0, Trials: 0
# Movie 45730 | Returns: 0, Trials: 0
# Movie 46530 | Returns: 0, Trials: 0
# Movie 48783 | Returns: 0, Trials: 0
# Movie 48997 | Returns: 0, Trials: 0
# Movie 49272 | Returns: 0, Trials: 0
# Movie 49278 | Returns: 0, Trials: 0
# Movie 49286 | Returns: 0, Trials: 0
# Movie 49824 | Returns: 0, Trials: 1
# Movie 586 | Returns: 0, Trials: 0
# Movie 187 | Returns: 0, Trials: 0
# Movie 627 | Returns: 0, Trials: 0
# Movie 922 | Returns: 1, Trials: 1
# Movie 1037 | Returns: 0, Trials: 0
# Movie 1095 | Returns: 0, Trials: 1
# Movie 1674 | Returns: 0, Trials: 0
# Movie 1987 | Returns: 0, Trials: 0
# Movie 2011 | Returns: 0, Trials: 0
# Movie 2023 | Returns: 0, Trials: 1
# Movie 2300 | Returns: 0, Trials: 1
# Movie 2877 | Returns: 0, Trials: 0
# Movie 2901 | Returns: 0, Trials: 0
# Movie 3173 | Returns: 0, Trials: 0
# Movie 3328 | Returns: 0, Trials: 0
# Movie 3735 | Returns: 0, Trials: 0
# Movie 4131 | Returns: 0, Trials: 0
# Movie 4558 | Returns: 0, Trials: 0
# Movie 5447 | Returns: 0, Trials: 0
# Movie 5451 | Returns: 0, Trials: 0
# Movie 5481 | Returns: 0, Trials: 0
# Movie 5507 | Returns: 0, Trials: 0
# Movie 5841 | Returns: 0, Trials: 0
# Movie 5843 | Returns: 0, Trials: 0
# Movie 5872 | Returns: 0, Trials: 0
# Movie 5890 | Returns: 0, Trials: 0
# Movie 5891 | Returns: 0, Trials: 0
# Movie 5893 | Returns: 0, Trials: 0
# Movie 5902 | Returns: 0, Trials: 0
# Movie 5956 | Returns: 0, Trials: 0
# Movie 5962 | Returns: 0, Trials: 1
# Movie 5965 | Returns: 0, Trials: 0
# Movie 5988 | Returns: 0, Trials: 0
# Movie 6001 | Returns: 0, Trials: 0
# Movie 6044 | Returns: 0, Trials: 0
# Movie 1028 | Returns: 0, Trials: 0
# Movie 1088 | Returns: 0, Trials: 0
# Movie 1247 | Returns: 0, Trials: 0
# Movie 1307 | Returns: 0, Trials: 0
# Movie 3882 | Returns: 0, Trials: 0
# Movie 4447 | Returns: 0, Trials: 0
# Movie 5066 | Returns: 0, Trials: 0
# Movie 5377 | Returns: 0, Trials: 0
# Movie 5620 | Returns: 0, Trials: 0
# Movie 5943 | Returns: 0, Trials: 0
# Movie 5957 | Returns: 0, Trials: 0
# Movie 6155 | Returns: 0, Trials: 1
# Movie 6266 | Returns: 0, Trials: 0
# Movie 6377 | Returns: 0, Trials: 0
# Movie 6535 | Returns: 0, Trials: 0
# Movie 6942 | Returns: 0, Trials: 0
# Movie 7149 | Returns: 0, Trials: 0
# Movie 7151 | Returns: 0, Trials: 0
# Movie 7154 | Returns: 0, Trials: 0
# Movie 7169 | Returns: 0, Trials: 0
# Movie 7293 | Returns: 0, Trials: 0
# Movie 7375 | Returns: 0, Trials: 1
# Movie 7451 | Returns: 0, Trials: 0
# Movie 7458 | Returns: 0, Trials: 0
# Movie 8529 | Returns: 0, Trials: 0
# Movie 8533 | Returns: 0, Trials: 0
# Movie 8869 | Returns: 0, Trials: 0
# Movie 8969 | Returns: 0, Trials: 0
# Movie 30749 | Returns: 0, Trials: 0
# Movie 31433 | Returns: 0, Trials: 0
# Movie 31685 | Returns: 0, Trials: 0
# Movie 33145 | Returns: 0, Trials: 0
# Movie 33679 | Returns: 0, Trials: 0
# Movie 40629 | Returns: 0, Trials: 0
# Movie 40819 | Returns: 0, Trials: 0
# Movie 41285 | Returns: 0, Trials: 0
# Movie 47099 | Returns: 0, Trials: 0
# Movie 51662 | Returns: 0, Trials: 0
# Movie 51705 | Returns: 0, Trials: 0
# Movie 51834 | Returns: 0, Trials: 0
# Movie 54286 | Returns: 0, Trials: 0
# Movie 56367 | Returns: 0, Trials: 0
# Movie 56949 | Returns: 0, Trials: 0
# Movie 58047 | Returns: 0, Trials: 0
# Movie 59333 | Returns: 0, Trials: 0
# Movie 59421 | Returns: 0, Trials: 0
# Movie 60397 | Returns: 0, Trials: 0
# Movie 60950 | Returns: 0, Trials: 0
# Movie 61250 | Returns: 0, Trials: 0
# Movie 63113 | Returns: 0, Trials: 0
# Movie 63992 | Returns: 0, Trials: 0
# Movie 64969 | Returns: 0, Trials: 1
# Movie 66203 | Returns: 0, Trials: 1
# Movie 68954 | Returns: 0, Trials: 0
# Movie 69406 | Returns: 0, Trials: 0
# Movie 69844 | Returns: 0, Trials: 1
# Movie 70183 | Returns: 0, Trials: 0
# Movie 70293 | Returns: 0, Trials: 0
# Movie 71579 | Returns: 0, Trials: 0
# Movie 72011 | Returns: 0, Trials: 1
# Movie 72330 | Returns: 0, Trials: 0
# Movie 72407 | Returns: 0, Trials: 0
# Movie 72720 | Returns: 0, Trials: 1
# Movie 72737 | Returns: 0, Trials: 0
# Movie 72998 | Returns: 0, Trials: 0
# Movie 73017 | Returns: 0, Trials: 0
# Movie 74450 | Returns: 0, Trials: 0
# Movie 77841 | Returns: 0, Trials: 0
# Movie 78772 | Returns: 0, Trials: 0
# Movie 79091 | Returns: 0, Trials: 0
# Movie 80549 | Returns: 0, Trials: 0
# Movie 81784 | Returns: 0, Trials: 0
# Movie 81845 | Returns: 0, Trials: 0
# Movie 81847 | Returns: 0, Trials: 0
# Movie 82167 | Returns: 0, Trials: 0
# Movie 82499 | Returns: 0, Trials: 0
# Movie 84374 | Returns: 0, Trials: 0
# Movie 86548 | Returns: 0, Trials: 0
# Movie 87222 | Returns: 0, Trials: 0
# Movie 88163 | Returns: 0, Trials: 0
# Movie 88810 | Returns: 0, Trials: 0
# Movie 91104 | Returns: 0, Trials: 0
# Movie 92259 | Returns: 0, Trials: 0
# Movie 94070 | Returns: 0, Trials: 0
# Movie 95167 | Returns: 0, Trials: 0
# Movie 95449 | Returns: 0, Trials: 1
# Movie 95510 | Returns: 0, Trials: 0
# Movie 95543 | Returns: 0, Trials: 0
# Movie 96079 | Returns: 0, Trials: 0
# Movie 97024 | Returns: 0, Trials: 0
# Movie 97938 | Returns: 0, Trials: 0
# Movie 98203 | Returns: 0, Trials: 0
# Movie 103335 | Returns: 0, Trials: 1
# Movie 103339 | Returns: 0, Trials: 0
# Movie 104374 | Returns: 0, Trials: 0
# Movie 105211 | Returns: 0, Trials: 0
# Movie 106489 | Returns: 0, Trials: 0
# Movie 106696 | Returns: 0, Trials: 0
# Movie 107141 | Returns: 0, Trials: 0
# Movie 109374 | Returns: 0, Trials: 0
# Movie 109853 | Returns: 0, Trials: 0
# Movie 112006 | Returns: 0, Trials: 0
# Movie 113275 | Returns: 0, Trials: 0
# ...
# Movie 116963 | Returns: 0, Trials: 0
# Movie 117630 | Returns: 0, Trials: 0
# Movie 118290 | Returns: 0, Trials: 0
# Movie 119218 | Returns: 0, Trials: 0
# Movie 119828 | Returns: 0, Trials: 0
# Movie 120827 | Returns: 0, Trials: 0
# Movie 121035 | Returns: 0, Trials: 1
# Movie 122260 | Returns: 0, Trials: 0
# Movie 122433 | Returns: 0, Trials: 0
# Movie 122627 | Returns: 0, Trials: 0
# Movie 123310 | Returns: 0, Trials: 0
# Movie 128197 | Returns: 0, Trials: 0
# Movie 128736 | Returns: 0, Trials: 0
# Movie 129779 | Returns: 0, Trials: 1
# Movie 131578 | Returns: 0, Trials: 0
# Movie 132084 | Returns: 0, Trials: 0
# Movie 132362 | Returns: 0, Trials: 1
# Movie 135787 | Returns: 0, Trials: 0
# Movie 136012 | Returns: 0, Trials: 0
# Movie 136297 | Returns: 0, Trials: 0
# Movie 137218 | Returns: 0, Trials: 1
# Movie 137345 | Returns: 0, Trials: 0
# Movie 137859 | Returns: 0, Trials: 0
# Movie 138702 | Returns: 0, Trials: 0
# Movie 139130 | Returns: 0, Trials: 0
# Movie 139859 | Returns: 0, Trials: 0
# Movie 140852 | Returns: 0, Trials: 0
# Movie 144522 | Returns: 0, Trials: 0
# Movie 145724 | Returns: 0, Trials: 0
# Movie 145745 | Returns: 0, Trials: 0
# Movie 151479 | Returns: 0, Trials: 1
# Movie 151781 | Returns: 0, Trials: 0
# Movie 153236 | Returns: 0, Trials: 0
# Movie 156675 | Returns: 0, Trials: 0
# Movie 157865 | Returns: 0, Trials: 0
# Movie 158388 | Returns: 0, Trials: 0
# Movie 158874 | Returns: 0, Trials: 0
# Movie 159061 | Returns: 0, Trials: 0
# Movie 159403 | Returns: 0, Trials: 1
# Movie 160978 | Returns: 0, Trials: 0
# Movie 161008 | Returns: 0, Trials: 0
# Movie 161032 | Returns: 0, Trials: 0
# Movie 161044 | Returns: 0, Trials: 0
# Movie 163809 | Returns: 0, Trials: 0
# Movie 165529 | Returns: 0, Trials: 0
# Movie 167706 | Returns: 0, Trials: 0
# Movie 168608 | Returns: 0, Trials: 0
# Movie 169670 | Returns: 0, Trials: 0
# Movie 169904 | Returns: 0, Trials: 0
# Movie 169958 | Returns: 0, Trials: 0
# Movie 170297 | Returns: 0, Trials: 0
# Movie 170551 | Returns: 0, Trials: 0
# Movie 171695 | Returns: 0, Trials: 0
# Movie 172229 | Returns: 0, Trials: 0
# Movie 172233 | Returns: 0, Trials: 0
# Movie 172253 | Returns: 0, Trials: 0
# Movie 173873 | Returns: 0, Trials: 1
# Movie 174727 | Returns: 0, Trials: 0
# Movie 178129 | Returns: 0, Trials: 1
# Movie 179053 | Returns: 0, Trials: 0
# Movie 181315 | Returns: 0, Trials: 0
# Movie 183301 | Returns: 0, Trials: 0
# Movie 2800 | Returns: 0, Trials: 0
# Movie 25905 | Returns: 0, Trials: 1
# Movie 25923 | Returns: 0, Trials: 0
# Movie 25947 | Returns: 1, Trials: 1
# Movie 46664 | Returns: 0, Trials: 0
# Movie 59131 | Returns: 0, Trials: 1
# Movie 141846 | Returns: 0, Trials: 0
# Movie 77 | Returns: 0, Trials: 0
# Movie 108 | Returns: 0, Trials: 0
# Movie 149 | Returns: 0, Trials: 0
# Movie 184 | Returns: 0, Trials: 0
# Movie 301 | Returns: 0, Trials: 0
# Movie 320 | Returns: 0, Trials: 0
# Movie 495 | Returns: 0, Trials: 0
# Movie 506 | Returns: 0, Trials: 0
# Movie 526 | Returns: 0, Trials: 0
# Movie 602 | Returns: 1, Trials: 1
# Movie 645 | Returns: 0, Trials: 1
# Movie 649 | Returns: 0, Trials: 0
# Movie 803 | Returns: 0, Trials: 0
# Movie 1053 | Returns: 0, Trials: 0
# Movie 1119 | Returns: 0, Trials: 0
# Movie 1310 | Returns: 1, Trials: 1
# Movie 1349 | Returns: 0, Trials: 0
# Movie 1475 | Returns: 0, Trials: 0
# Movie 1514 | Returns: 0, Trials: 0
# Movie 1549 | Returns: 0, Trials: 0
# Movie 1585 | Returns: 0, Trials: 0
# Movie 1612 | Returns: 0, Trials: 0
# Movie 1613 | Returns: 1, Trials: 1
# Movie 1759 | Returns: 0, Trials: 0
# Movie 2008 | Returns: 0, Trials: 0
# Movie 2104 | Returns: 0, Trials: 0
# Movie 2283 | Returns: 0, Trials: 0
# Movie 2304 | Returns: 0, Trials: 0
# Movie 2417 | Returns: 0, Trials: 0
# Movie 2435 | Returns: 0, Trials: 0
# Movie 2512 | Returns: 0, Trials: 0
# Movie 2544 | Returns: 0, Trials: 0
# Movie 2577 | Returns: 0, Trials: 1
# Movie 2609 | Returns: 0, Trials: 0
# Movie 2620 | Returns: 0, Trials: 0
# Movie 2725 | Returns: 0, Trials: 0
# Movie 2727 | Returns: 0, Trials: 0
# Movie 2813 | Returns: 0, Trials: 0
# Movie 2865 | Returns: 0, Trials: 0
# Movie 2885 | Returns: 0, Trials: 0
# Movie 2892 | Returns: 0, Trials: 0
# Movie 2972 | Returns: 0, Trials: 0
# Movie 3002 | Returns: 1, Trials: 1
# Movie 3183 | Returns: 0, Trials: 1
# Movie 3303 | Returns: 0, Trials: 0
# Movie 3344 | Returns: 0, Trials: 0
# Movie 3374 | Returns: 0, Trials: 0
# Movie 3459 | Returns: 0, Trials: 0
# Movie 3514 | Returns: 0, Trials: 0
# Movie 3531 | Returns: 0, Trials: 0
# Movie 3586 | Returns: 0, Trials: 0
# Movie 3637 | Returns: 0, Trials: 0
# Movie 3655 | Returns: 0, Trials: 0
# Movie 3792 | Returns: 0, Trials: 0
# Movie 4420 | Returns: 0, Trials: 0
# Movie 4428 | Returns: 0, Trials: 0
# Movie 4436 | Returns: 0, Trials: 0
# Movie 4690 | Returns: 0, Trials: 0
# Movie 4695 | Returns: 0, Trials: 0
# Movie 4705 | Returns: 0, Trials: 0
# Movie 4766 | Returns: 0, Trials: 0
# Movie 4786 | Returns: 0, Trials: 0
# Movie 4810 | Returns: 0, Trials: 0
# Movie 117 | Returns: 0, Trials: 0
# Movie 220 | Returns: 0, Trials: 0
# Movie 285 | Returns: 1, Trials: 1
# Movie 311 | Returns: 0, Trials: 0
# Movie 636 | Returns: 0, Trials: 0
# Movie 1654 | Returns: 0, Trials: 0
# Movie 27036 | Returns: 0, Trials: 0
# Movie 35347 | Returns: 0, Trials: 0
# Movie 47384 | Returns: 0, Trials: 0
# Movie 54686 | Returns: 0, Trials: 0
# Movie 65359 | Returns: 0, Trials: 0
# Movie 66240 | Returns: 0, Trials: 0
# Movie 71160 | Returns: 0, Trials: 0
# Movie 72165 | Returns: 0, Trials: 0
# Movie 72982 | Returns: 0, Trials: 0
# Movie 202 | Returns: 0, Trials: 0
# Movie 263 | Returns: 0, Trials: 0
# Movie 563 | Returns: 2, Trials: 2
# Movie 573 | Returns: 0, Trials: 0
# Movie 579 | Returns: 0, Trials: 1
# Movie 583 | Returns: 0, Trials: 0
# Movie 632 | Returns: 0, Trials: 0
# Movie 961 | Returns: 0, Trials: 0
# Movie 1117 | Returns: 0, Trials: 0
# Movie 1156 | Returns: 0, Trials: 1
# Movie 1493 | Returns: 0, Trials: 0
# Movie 1857 | Returns: 0, Trials: 0
# Movie 2156 | Returns: 0, Trials: 0
# Movie 2207 | Returns: 0, Trials: 0
# Movie 2388 | Returns: 0, Trials: 0
# Movie 2481 | Returns: 0, Trials: 0
# Movie 2503 | Returns: 0, Trials: 0
# Movie 2897 | Returns: 0, Trials: 0
# Movie 3010 | Returns: 0, Trials: 0
# Movie 3289 | Returns: 1, Trials: 1
# Movie 3295 | Returns: 0, Trials: 0
# Movie 3640 | Returns: 0, Trials: 0
# Movie 3808 | Returns: 0, Trials: 0
# Movie 3920 | Returns: 0, Trials: 0
# Movie 4357 | Returns: 0, Trials: 0
# Movie 4395 | Returns: 0, Trials: 0
# Movie 4615 | Returns: 0, Trials: 0
# Movie 4653 | Returns: 0, Trials: 1
# Movie 4671 | Returns: 0, Trials: 0
# Movie 4689 | Returns: 0, Trials: 0
# Movie 4828 | Returns: 0, Trials: 0
# Movie 4840 | Returns: 1, Trials: 1
# Movie 4883 | Returns: 0, Trials: 0
# Movie 5269 | Returns: 0, Trials: 0
# Movie 5372 | Returns: 0, Trials: 0
# Movie 5503 | Returns: 0, Trials: 0
# Movie 5550 | Returns: 0, Trials: 0
# Movie 5614 | Returns: 0, Trials: 0
# Movie 5720 | Returns: 0, Trials: 0
# Movie 5733 | Returns: 0, Trials: 0
# Movie 5741 | Returns: 0, Trials: 0
# Movie 5742 | Returns: 1, Trials: 1
# Movie 5849 | Returns: 0, Trials: 0
# Movie 5856 | Returns: 0, Trials: 0
# Movie 5922 | Returns: 0, Trials: 0
# Movie 5929 | Returns: 0, Trials: 0
# Movie 5975 | Returns: 0, Trials: 0
# Movie 5990 | Returns: 0, Trials: 0
# Movie 6070 | Returns: 0, Trials: 0
# Movie 6107 | Returns: 0, Trials: 0
# Movie 6111 | Returns: 0, Trials: 0
# Movie 6182 | Returns: 0, Trials: 0
# Movie 6202 | Returns: 0, Trials: 0
# Movie 6237 | Returns: 0, Trials: 0
# Movie 6415 | Returns: 0, Trials: 0
# Movie 6449 | Returns: 0, Trials: 0
# Movie 6516 | Returns: 0, Trials: 0
# Movie 6553 | Returns: 0, Trials: 0
# Movie 6573 | Returns: 0, Trials: 0
# Movie 6578 | Returns: 0, Trials: 0
# Movie 6644 | Returns: 0, Trials: 0
# Movie 6671 | Returns: 0, Trials: 0
# Movie 6782 | Returns: 0, Trials: 0
# Movie 6789 | Returns: 0, Trials: 0
# Movie 6803 | Returns: 0, Trials: 0
# Movie 6961 | Returns: 0, Trials: 0
# Movie 6973 | Returns: 0, Trials: 0
# Movie 7037 | Returns: 1, Trials: 1
# Movie 7109 | Returns: 0, Trials: 1
# Movie 7131 | Returns: 0, Trials: 0
# Movie 7292 | Returns: 0, Trials: 0
# Movie 7344 | Returns: 0, Trials: 0
# Movie 7487 | Returns: 1, Trials: 1
# Movie 7916 | Returns: 0, Trials: 0
# Movie 8391 | Returns: 0, Trials: 0
# Movie 8454 | Returns: 0, Trials: 0
# Movie 8456 | Returns: 0, Trials: 0
# Movie 8601 | Returns: 1, Trials: 1
# Movie 8685 | Returns: 0, Trials: 0
# Movie 8713 | Returns: 0, Trials: 0
# Movie 8933 | Returns: 0, Trials: 0
# Movie 8964 | Returns: 0, Trials: 0
# Movie 25805 | Returns: 0, Trials: 0
# Movie 25833 | Returns: 0, Trials: 0
# Movie 25946 | Returns: 0, Trials: 0
# Movie 26038 | Returns: 0, Trials: 0
# Movie 26394 | Returns: 2, Trials: 2
# Movie 26527 | Returns: 0, Trials: 0
# Movie 26599 | Returns: 0, Trials: 0
# Movie 26777 | Returns: 0, Trials: 0
# Movie 26796 | Returns: 0, Trials: 0
# Movie 26875 | Returns: 0, Trials: 0
# Movie 26985 | Returns: 0, Trials: 0
# Movie 27178 | Returns: 0, Trials: 0
# Movie 27255 | Returns: 0, Trials: 0
# Movie 27627 | Returns: 0, Trials: 0
# Movie 27644 | Returns: 0, Trials: 0
# Movie 27744 | Returns: 0, Trials: 0
# Movie 30890 | Returns: 0, Trials: 0
# Movie 30994 | Returns: 1, Trials: 1
# Movie 31309 | Returns: 0, Trials: 0
# Movie 31973 | Returns: 0, Trials: 0
# Movie 32234 | Returns: 0, Trials: 0
# Movie 32600 | Returns: 0, Trials: 0
# Movie 32620 | Returns: 0, Trials: 0
# Movie 32649 | Returns: 0, Trials: 0
# Movie 32728 | Returns: 0, Trials: 0
# Movie 32862 | Returns: 0, Trials: 0
# Movie 33237 | Returns: 0, Trials: 0
# Movie 33310 | Returns: 0, Trials: 0
# Movie 41014 | Returns: 1, Trials: 1
# Movie 44189 | Returns: 0, Trials: 0
# Movie 44301 | Returns: 0, Trials: 0
# Movie 47202 | Returns: 0, Trials: 0
# Movie 47538 | Returns: 0, Trials: 0
# Movie 47774 | Returns: 0, Trials: 0
# Movie 48032 | Returns: 1, Trials: 1
# Movie 48214 | Returns: 0, Trials: 1
# Movie 50354 | Returns: 0, Trials: 0
# Movie 50356 | Returns: 0, Trials: 1
# Movie 51314 | Returns: 0, Trials: 0
# Movie 55805 | Returns: 0, Trials: 0
# Movie 56333 | Returns: 0, Trials: 0
# Movie 58783 | Returns: 0, Trials: 0
# Movie 68480 | Returns: 0, Trials: 0
# Movie 68872 | Returns: 0, Trials: 0
# Movie 69224 | Returns: 0, Trials: 0
# Movie 72603 | Returns: 0, Trials: 0
# Movie 241 | Returns: 1, Trials: 1
# Movie 2737 | Returns: 0, Trials: 0
# Movie 5901 | Returns: 0, Trials: 0
# Movie 7377 | Returns: 0, Trials: 0
# Movie 8667 | Returns: 0, Trials: 0
# Movie 32302 | Returns: 0, Trials: 0
# Movie 51903 | Returns: 0, Trials: 0
# Movie 137 | Returns: 0, Trials: 0
# Movie 1054 | Returns: 0, Trials: 0
# Movie 3945 | Returns: 0, Trials: 0
# Movie 4497 | Returns: 0, Trials: 0
# Movie 5275 | Returns: 0, Trials: 0
# Movie 5953 | Returns: 0, Trials: 0
# Movie 6009 | Returns: 0, Trials: 0
# Movie 6095 | Returns: 0, Trials: 0
# Movie 7202 | Returns: 0, Trials: 0
# Movie 7562 | Returns: 0, Trials: 0
# Movie 7984 | Returns: 0, Trials: 0
# Movie 8840 | Returns: 0, Trials: 0
# Movie 26169 | Returns: 0, Trials: 0
# Movie 26391 | Returns: 0, Trials: 1
# Movie 26399 | Returns: 0, Trials: 0
# Movie 26401 | Returns: 0, Trials: 0
# Movie 26498 | Returns: 0, Trials: 0
# Movie 26603 | Returns: 0, Trials: 0
# Movie 27426 | Returns: 0, Trials: 0
# Movie 27480 | Returns: 0, Trials: 0
# Movie 27491 | Returns: 0, Trials: 0
# Movie 27746 | Returns: 0, Trials: 0
# Movie 27778 | Returns: 0, Trials: 0
# Movie 27905 | Returns: 0, Trials: 0
# Movie 31086 | Returns: 0, Trials: 0
# Movie 34450 | Returns: 0, Trials: 0
# Movie 36931 | Returns: 0, Trials: 0
# Movie 41712 | Returns: 0, Trials: 0
# Movie 43289 | Returns: 0, Trials: 0
# Movie 44597 | Returns: 0, Trials: 0
# Movie 47937 | Returns: 0, Trials: 0
# Movie 48150 | Returns: 0, Trials: 0
# Movie 51666 | Returns: 0, Trials: 0
# Movie 52831 | Returns: 0, Trials: 0
# Movie 54910 | Returns: 0, Trials: 0
# Movie 55067 | Returns: 0, Trials: 0
# Movie 55492 | Returns: 0, Trials: 0
# Movie 56620 | Returns: 0, Trials: 0
# Movie 57421 | Returns: 0, Trials: 0
# Movie 57637 | Returns: 0, Trials: 0
# Movie 58826 | Returns: 0, Trials: 0
# Movie 58964 | Returns: 0, Trials: 0
# Movie 58975 | Returns: 0, Trials: 0
# Movie 59915 | Returns: 0, Trials: 1
# Movie 60303 | Returns: 0, Trials: 0
# Movie 60471 | Returns: 0, Trials: 0
# Movie 61262 | Returns: 0, Trials: 1
# Movie 61319 | Returns: 0, Trials: 0
# Movie 61692 | Returns: 0, Trials: 1
# Movie 61818 | Returns: 0, Trials: 0
# Movie 63179 | Returns: 0, Trials: 0
# Movie 63768 | Returns: 0, Trials: 0
# Movie 63826 | Returns: 0, Trials: 0
# Movie 64010 | Returns: 0, Trials: 0
# Movie 66310 | Returns: 0, Trials: 0
# Movie 67168 | Returns: 0, Trials: 0
# Movie 70206 | Returns: 0, Trials: 0
# Movie 70208 | Returns: 0, Trials: 0
# Movie 71341 | Returns: 0, Trials: 0
# Movie 71910 | Returns: 0, Trials: 0
# Movie 72142 | Returns: 0, Trials: 0
# Movie 72424 | Returns: 0, Trials: 0
# Movie 73676 | Returns: 0, Trials: 0
# Movie 73741 | Returns: 0, Trials: 0
# Movie 73876 | Returns: 0, Trials: 0
# Movie 74370 | Returns: 0, Trials: 0
# Movie 75389 | Returns: 0, Trials: 0
# Movie 76091 | Returns: 0, Trials: 0
# Movie 77893 | Returns: 0, Trials: 0
# Movie 77931 | Returns: 0, Trials: 0
# Movie 78626 | Returns: 0, Trials: 0
# Movie 79501 | Returns: 0, Trials: 0
# Movie 79868 | Returns: 0, Trials: 0
# Movie 80094 | Returns: 0, Trials: 0
# Movie 80162 | Returns: 0, Trials: 0
# Movie 81520 | Returns: 0, Trials: 0
# Movie 82366 | Returns: 0, Trials: 0
# Movie 82641 | Returns: 0, Trials: 0
# Movie 82765 | Returns: 0, Trials: 0
# Movie 88327 | Returns: 0, Trials: 0
# Movie 89072 | Returns: 0, Trials: 0
# Movie 89281 | Returns: 0, Trials: 0
# Movie 89837 | Returns: 0, Trials: 0
# Movie 91233 | Returns: 0, Trials: 0
# Movie 93193 | Returns: 0, Trials: 0
# Movie 93598 | Returns: 0, Trials: 0
# Movie 93819 | Returns: 0, Trials: 0
# Movie 94867 | Returns: 0, Trials: 1
# Movie 96832 | Returns: 0, Trials: 0
# Movie 97188 | Returns: 0, Trials: 0
# Movie 97285 | Returns: 0, Trials: 0
# Movie 97701 | Returns: 0, Trials: 1
# Movie 97988 | Returns: 0, Trials: 0
# Movie 98061 | Returns: 0, Trials: 0
# Movie 98633 | Returns: 0, Trials: 0
# Movie 99030 | Returns: 0, Trials: 0
# Movie 99721 | Returns: 0, Trials: 0
# Movie 100159 | Returns: 0, Trials: 0
# Movie 100397 | Returns: 0, Trials: 0
# Movie 100579 | Returns: 0, Trials: 0
# Movie 100906 | Returns: 0, Trials: 0
# Movie 102066 | Returns: 1, Trials: 1
# Movie 102070 | Returns: 0, Trials: 0
# Movie 102338 | Returns: 0, Trials: 0
# Movie 102760 | Returns: 0, Trials: 0
# Movie 102802 | Returns: 0, Trials: 1
# Movie 103085 | Returns: 0, Trials: 0
# Movie 103219 | Returns: 0, Trials: 0
# Movie 103483 | Returns: 0, Trials: 0
# Movie 103685 | Returns: 0, Trials: 0
# Movie 105801 | Returns: 0, Trials: 0
# Movie 107436 | Returns: 0, Trials: 0
# Movie 107447 | Returns: 0, Trials: 0
# Movie 107462 | Returns: 0, Trials: 0
# Movie 107771 | Returns: 0, Trials: 0
# Movie 110281 | Returns: 0, Trials: 0
# Movie 110286 | Returns: 0, Trials: 0
# Movie 110591 | Returns: 0, Trials: 0
# Movie 110746 | Returns: 0, Trials: 0
# Movie 111551 | Returns: 0, Trials: 0
# Movie 112727 | Returns: 0, Trials: 0
# Movie 113159 | Returns: 0, Trials: 0
# Movie 113313 | Returns: 0, Trials: 0
# Movie 113565 | Returns: 0, Trials: 0
# Movie 113780 | Returns: 0, Trials: 0
# Movie 113862 | Returns: 0, Trials: 0
# Movie 114044 | Returns: 0, Trials: 0
# Movie 114670 | Returns: 0, Trials: 0
# Movie 114707 | Returns: 0, Trials: 0
# Movie 115727 | Returns: 0, Trials: 0
# Movie 117867 | Returns: 0, Trials: 0
# Movie 118082 | Returns: 0, Trials: 0
# Movie 128838 | Returns: 0, Trials: 1
# Movie 129313 | Returns: 0, Trials: 0
# Movie 130050 | Returns: 0, Trials: 0
# Movie 130052 | Returns: 0, Trials: 0
# Movie 130840 | Returns: 0, Trials: 0
# Movie 133832 | Returns: 0, Trials: 0
# Movie 135534 | Returns: 0, Trials: 0
# Movie 135803 | Returns: 0, Trials: 0
# Movie 135815 | Returns: 0, Trials: 0
# Movie 138610 | Returns: 0, Trials: 0
# Movie 138632 | Returns: 0, Trials: 0
# Movie 139511 | Returns: 0, Trials: 0
# Movie 139655 | Returns: 0, Trials: 0
# Movie 140267 | Returns: 0, Trials: 0
# Movie 141400 | Returns: 0, Trials: 0
# Movie 141799 | Returns: 0, Trials: 0
# Movie 142366 | Returns: 0, Trials: 0
# Movie 142598 | Returns: 0, Trials: 0
# Movie 145951 | Returns: 0, Trials: 0
# Movie 146309 | Returns: 0, Trials: 0
# Movie 147657 | Returns: 0, Trials: 0
# Movie 147662 | Returns: 0, Trials: 0
# Movie 148166 | Returns: 0, Trials: 0
# Movie 149011 | Returns: 0, Trials: 0
# Movie 152372 | Returns: 0, Trials: 0
# Movie 158721 | Returns: 0, Trials: 0
# Movie 160341 | Returns: 0, Trials: 0
# Movie 160527 | Returns: 0, Trials: 0
# Movie 160836 | Returns: 0, Trials: 0
# Movie 163937 | Returns: 0, Trials: 0
# Movie 163981 | Returns: 0, Trials: 0
# ===== Total Returns: 249 =====

# %% [markdown]
# # Using Random Policy (0.5M)
# Implement a random policy for movie recommendations and print each iteration. (Mandatory)

# %%
#  run the environment with an agent that is guided by a random policy
#-----write your code below this line---------

# %% [markdown]
# # Using Greedy Policy (1M)
# Implement a greedy policy that always recommends the movie with the highest estimated reward and print each iteration. (Mandatory)

# %%
#  run the environment with an agent that is guided by a greedy policy
#-----write your code below this line---------

# %% [markdown]
# # Using Epsilon-Greedy Policy (1.5M)
# Implement the epsilon-greedy policy, where with probability ε you explore (recommend a random movie) and with probability (1-ε) you exploit (recommend the best-known movie). Try with ε =0.1, 0.2, 0.5 and print each iteration. What value of ε yields the best performance? (Mandatory)

# %%
#  run the environment with an agent that is guided by a epsilon-greedy policy
#-----write your code below this line---------

# %% [markdown]
# # Using UCB (1M)
# Implement the UCB algorithm for movie recommendations and print each iteration. (Mandatory)

# %%
#  run the environment with an agent that is guided by a UCB
#-----write your code below this line---------

# %% [markdown]
# # Plot the cumulative rewards for all policies on a single graph to compare their performance. (0.5M)

# %%
#-----write your code below this line---------

# %% [markdown]
# # Conclusion (0.5M)
#
# Determine which policy performs the best based on cumulative reward. Provide a concise conclusion (250 words) summarizing the decision-making process and the trade-offs between exploration and exploitation.
#
# `----write below this line------`
