# %% [markdown]
# ## Group No
#
# ## Group Member Names:
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# # 1. Import the required libraries

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import re
import string
import matplotlib.pyplot as plt
import pandas as pd
# Set device (TensorFlow automatically selects available GPU)
device = "GPU" if tf.config.list_physical_devices('GPU') else "CPU"

print(f"Using device: {device}")
# Out:
# Using device: CPU

# %% [markdown]
# # 2. Data Acquisition  -- Score: 0.5 Mark
#
# For the problem identified by you, students have to find the data source themselves from any data source.
#
# ## 2.1 Code for converting the above downloaded data into a form suitable for DL

# %%
# Load IMDB dataset from TensorFlow Datasets
dataset, info = tfds.load('imdb_reviews', with_info=True, as_supervised=True)
train_data, test_data = dataset['train'], dataset['test']
# Out:
# Downloading and preparing dataset 80.23 MiB (download: 80.23 MiB, generated: Unknown size, total: 80.23 MiB) to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.ZKDCPV_1.0.0/imdb_reviews-train.tfrecor…
# Generating test examples...:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.ZKDCPV_1.0.0/imdb_reviews-test.tfrecord…
# Generating unsupervised examples...:   0%|          | 0/50000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/imdb_reviews/plain_text/incomplete.ZKDCPV_1.0.0/imdb_reviews-unsupervised.…
# Dataset imdb_reviews downloaded and prepared to /root/tensorflow_datasets/imdb_reviews/plain_text/1.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# ## 2.1 Write your observations from the above.
#
# 1. Size of the dataset
# 2. What type of data attributes are there?
# 3. What are you classifying?
# 4. Plot the distribution of the categories of the target / label.

# %%
# Print dataset size
print(f"Size of Training Data: {len(list(train_data))}")
print(f"Size of Test Data: {len(list(test_data))}")

# Extract data types of attributes
for text, label in train_data.take(1):
    print("\nData Attribute Types:")
    print(f"Review Text Type: {type(text.numpy().decode('utf-8'))}")  # Should be str
    print(f"Sentiment Label Type: {type(label.numpy())}")  # Should be int (0 or 1)

# Extract one positive and one negative sample
positive_sample = None
negative_sample = None

for text, label in train_data:
    if label.numpy() == 1 and positive_sample is None:
        positive_sample = (text.numpy().decode('utf-8'), "Positive")
    elif label.numpy() == 0 and negative_sample is None:
        negative_sample = (text.numpy().decode('utf-8'), "Negative")

    if positive_sample and negative_sample:
        break  # Stop once we have both samples

# Print the samples
print("\nNegative Review Sample:\n", negative_sample[0])
print("Label:", negative_sample[1])

print("\nPositive Review Sample:\n", positive_sample[0])
print("Label:", positive_sample[1])

# Classifying between positive (1) and negative (0) movie reviews
print("\nWe are classifying movie reviews into Positive (1) or Negative (0).")

# Count the number of positive and negative reviews
num_positive = sum(1 for _, label in train_data if label.numpy() == 1)
num_negative = sum(1 for _, label in train_data if label.numpy() == 0)

# Print the counts
print(f"Number of Positive Reviews: {num_positive}")
print(f"Number of Negative Reviews: {num_negative}")

# Plot a pie chart
plt.figure(figsize=(6, 6))
plt.pie([num_negative, num_positive], labels=['Negative', 'Positive'], autopct='%1.1f%%',
        colors=['red', 'green'], startangle=90, wedgeprops={'edgecolor': 'black'})
plt.title("Distribution of Sentiment Classes in IMDB Dataset")
plt.show()
# Out:
# Size of Training Data: 25000
# Size of Test Data: 25000
#
# Data Attribute Types:
# Review Text Type: <class 'str'>
# Sentiment Label Type: <class 'numpy.int64'>
#
# Negative Review Sample:
#  This was an absolutely terrible movie. Don't be lured in by Christopher Walken or Michael Ironside. Both are great actors, but this must simply be their worst role in history. Even their great acting could not redeem this movie's ridiculous storyline. This movie is an early nineties US propaganda piece. The most pathetic scenes were those when the Columbian rebels were making their cases for revolutions. Maria Conchita Alonso appeared phony, and her pseudo-love affair with Walken was nothing but a pathetic emotional plug in a movie that was devoid of any real meaning. I am disappointed that there are movies like this, ruining actor's like Christopher Walken's good name. I could barely sit through it.
# Label: Negative
#
# Positive Review Sample:
#  This is the kind of film for a snowy Sunday afternoon when the rest of the world can go ahead with its own business as you descend into a big arm-chair and mellow for a couple of hours. Wonderful performances from Cher and Nicolas Cage (as always) gently row the plot along. There are no rapids to cross, no dangerous waters, just a warm and witty paddle through New York life at its best. A family film in every sense and one that deserves the praise it received.
# Label: Positive
#
# We are classifying movie reviews into Positive (1) or Negative (0).
# Number of Positive Reviews: 12500
# Number of Negative Reviews: 12500

# %% [markdown]
# # 3. Data Preparation -- Score: 1 Mark
#
# Perform the data prepracessing that is required for the data that you have downloaded.
#
#
# This stage depends on the dataset that is used.

# %% [markdown]
# ## 3.1 Apply pre-processing techiniques
#
# * to remove duplicate data
# * to impute or remove missing data
# * to remove data inconsistencies
# * Encode categorical data
# * Normalize the data
# * Feature Engineering
# * Stop word removal, lemmatiation, stemming, vectorization
#
#
# IF ANY

# %% [markdown]
# Let's do the following pre-processing steps.

# %%
import pandas as pd

# Convert dataset to Pandas DataFrame for train and test
def dataset_to_dataframe(dataset):
    texts = [text.numpy().decode('utf-8') for text, label in dataset]
    labels = [label.numpy() for text, label in dataset]
    return pd.DataFrame({"review": texts, "label": labels})

# Convert train and test datasets
df_train = dataset_to_dataframe(train_data)
df_test = dataset_to_dataframe(test_data)

# Check and remove duplicates in both datasets
for name, df in [("Training", df_train), ("Test", df_test)]:
    num_duplicates = df.duplicated().sum()
    print(f"Number of Duplicate Entries in {name} Data: {num_duplicates}")

    if num_duplicates > 0:
      df.drop_duplicates(inplace=True)
      df.reset_index(drop=True, inplace=True)
# Out:
# Number of Duplicate Entries in Training Data: 96
# Number of Duplicate Entries in Test Data: 199

# %%
# Check for missing values in both datasets
for name, df in [("Training", df_train), ("Test", df_test)]:
    missing_values = df.isnull().sum()
    print(f"\nMissing Values in {name} Data:\n{missing_values}")

    # Drop missing values if any
    if missing_values.sum() > 0:
        df.dropna(inplace=True)
# Out:
# Missing Values in Training Data:
# review    0
# label     0
# dtype: int64
#
# Missing Values in Test Data:
# review    0
# label     0
# dtype: int64

# %%
# Checking for empty reviews in both datasets
for name, df in [("Training", df_train), ("Test", df_test)]:
    empty_reviews = (df['review'].str.strip() == "").sum()
    print(f"Number of Empty Reviews in {name} Data: {empty_reviews}")

    # Drop empty reviews if any
    if empty_reviews > 0:
        df = df[df['review'].str.strip() != ""].reset_index(drop=True)
# Out:
# Number of Empty Reviews in Training Data: 0
# Number of Empty Reviews in Test Data: 0

# %%
import nltk
import re
import string
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('stopwords')
nltk.download('wordnet')

# Initialize stopwords and lemmatizer
stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

# Define preprocessing function
def preprocess_text(text):
    text = text.lower()  # Convert to lowercase
    text = re.sub(f"[{re.escape(string.punctuation)}]", "", text)  # Remove punctuation
    text = re.sub("\\s+", " ", text).strip()  # Remove extra spaces
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]  # Remove stopwords & lemmatize
    return " ".join(words)

# Apply preprocessing to both train and test datasets
for name, df in [("Training", df_train), ("Test", df_test)]:
    df["cleaned_review"] = df["review"].apply(preprocess_text)
    print(f"Preprocessing completed for {name} dataset.")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Preprocessing completed for Training dataset.
# Preprocessing completed for Test dataset.

# %% [markdown]
# ## 3.2 Identify the target variables.
#
# * Separate the data front the target such that the dataset is in the form of (X,y) or (Features, Label)
#
# * Discretize / Encode the target variable or perform one-hot encoding on the target or any other as and if required.

# %%
##---------Type the code below this line------------------##

# Use TextVectorization with TF-IDF output for Dense layers
encoder = tf.keras.layers.TextVectorization(output_mode='tf-idf', max_tokens=10000)  # Limit vocabulary size

# Learn vocabulary and compute TF-IDF weights from training data
encoder.adapt(df_train["cleaned_review"].to_numpy())

# Print vocab size after adaptation
print(f"\nVocabulary Size After Adaptation: {len(encoder.get_vocabulary())}")

# Transform train and test sets into TF-IDF feature matrices
X_train = encoder(df_train["cleaned_review"]).numpy()
X_test = encoder(df_test["cleaned_review"]).numpy()

# Convert labels to numpy arrays
y_train = df_train["label"].to_numpy()
y_test = df_test["label"].to_numpy()
# Out:
# Vocabulary Size After Adaptation: 10000

# %% [markdown]
# ## 3.3 Split the data into training set and testing set

# %%
# The data is already split into training and test from the source
# Check the shape of the transformed data
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (24904, 10000), y_train shape: (24904,)
# X_test shape: (24801, 10000), y_test shape: (24801,)

# %% [markdown]
# ## 3.4 Preprocessing report
#
# Mention the method adopted  and justify why the method was used
# * to remove duplicate data, if present
# * to impute or remove missing data, if present
# * to remove data inconsistencies, if present
# * to encode categorical data
# * the normalization technique used
#
# If the any of the above are not present, then also add in the report below.
#
# Report the size of the training dataset and testing dataset

# %% [markdown]
# **The preprocessing methods are done above**
# 1. Removing Duplicates - Prevents overfitting by ensuring unique reviews.
# 2. Handling Missing Data - Avoids errors from empty reviews or labels.
# 3. Removing Data Inconsistencies - Cleans unnecessary symbols and formatting issues.
# 4. Encoding Categorical Data - Converts sentiment labels into numerical format.
# 5. Normalization - Maintains consistent review lengths for efficient processing.
# 6. Feature Engineering - Enhances sentiment detection by emphasizing important words.
# 7. Stop Word Removal - Reduces noise by eliminating non-informative words.
# 8. Lemmatization/Stemming - Standardizes word forms for better generalization.
# 9. Vectorization - Converts text into numerical representations for model training.

# %%
##---------Type the answer below this line------------------##
print(f"Number of Training Samples: {len(df_train)}")
print(f"Number of Test Samples: {len(df_test)}")
# Out:
# Number of Training Samples: 24904
# Number of Test Samples: 24801

# %% [markdown]
# # 4. Deep Neural Network Architecture - Score:  Marks

# %% [markdown]
# ## 4.1 Design the architecture that you will be using
#
# * Sequential Model Building with Activation for each layer.
# * Add dense layers, specifying the number of units in each layer and the activation function used in the layer.
# * Use Relu Activation function in each hidden layer
# * Use Sigmoid / softmax Activation function in the output layer as required
#
# DO NOT USE CNN OR RNN.

# %%
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(input_dim=len(encoder.get_vocabulary()), output_dim=256, input_length=256),
#     tf.keras.layers.Flatten(),
#     tf.keras.layers.Dense(256, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dropout(0.4),
#     tf.keras.layers.Dense(64, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dropout(0.3),
#     tf.keras.layers.Dense(1, activation='sigmoid')
# ])
# model = tf.keras.Sequential([
#     tf.keras.layers.Embedding(input_dim=len(encoder.get_vocabulary()), output_dim=256, input_length=256),
#     tf.keras.layers.Flatten(),  # Convert embeddings into a 1D vector
#     tf.keras.layers.Dense(256, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(128, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.Dense(1, activation='sigmoid')  # Binary classification output
# ])

def create_model():
  model = tf.keras.Sequential([
      tf.keras.layers.Input(shape=(X_train.shape[1],)),  # Input shape matches TF-IDF output
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.BatchNormalization(),
      tf.keras.layers.Dense(1, activation='sigmoid')
  ])
  return model

model = create_model()

# %% [markdown]
# ## 4.2 DNN Report
#
# Report the following and provide justification for the same.
#
#
#
# * Number of layers
# * Number of units in each layer
# * Total number of trainable parameters

# %%
##---------Type the answer below this line------------------##
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │       1,280,128 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,289,217 (4.92 MB)
#  Trainable params: 1,288,833 (4.92 MB)
#  Non-trainable params: 384 (1.50 KB)

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, show_layer_activations=True, dpi=80)

# %% [markdown]
# # 5. Training the model - Score: 1 Mark

# %% [markdown]
# ## 5.1 Configure the training
#
# Configure  the model for training, by using appropriate optimizers and regularizations
#
# Compile with categorical CE loss and metric accuracy.

# %%
##---------Type the code below this line------------------##

# Function to compile & fit models
def compile_model(model, learning_rate=0.01, momentum=0.9):
  print('Model compiling')
  # Compile with SGD
  model.compile(loss='binary_crossentropy',
            optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=momentum),
            metrics=['accuracy'])
  return model

def fit_model(model, X_train, y_train, X_test, y_test):
  print('Model training started')
  history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test, y_test), batch_size=64)
  return history

# %% [markdown]
# ## 5.2 Train the model
#
# Train Model with cross validation, with total time taken shown for 20 epochs.
#
# Use SGD.

# %%
from sklearn.model_selection import KFold
import time
import itertools

# Define hyperparameter grid
LEARNING_RATES = [0.1, 0.005, 0.01]
MOMENTUMS = [0.8, 0.9, 0.95]

def train_model_cv(X_train, y_train, X_test, y_test, k=3):
    print('Cross-validation training started...')
    kf = KFold(n_splits=k, shuffle=True, random_state=42)  # 5-Fold Cross Validation

    best_hyperparams = None
    best_mean_accuracy = 0.0
    results = []

    start_time = time.time()  # Track total time

    # Iterate over all hyperparameter combinations
    for learning_rate, momentum in itertools.product(LEARNING_RATES, MOMENTUMS):
        print(f"\nEvaluating Hyperparameters: Learning Rate={learning_rate}, Momentum={momentum}")

        fold_accuracies = []
        fold_losses = []

        for fold, (train_idx, val_idx) in enumerate(kf.split(X_train)):
            print(f"\nTraining Fold {fold+1}/{k}...")

            X_train_fold, X_val_fold = X_train[train_idx], X_train[val_idx]
            y_train_fold, y_val_fold = y_train[train_idx], y_train[val_idx]

            # Create and compile model
            model = create_model()
            model = compile_model(model, learning_rate=learning_rate, momentum=momentum)

            # Train on fold
            history = fit_model(model, X_train_fold, y_train_fold, X_val_fold, y_val_fold)

            # Store accuracy & loss
            fold_accuracies.append(history.history['val_accuracy'][-1])
            fold_losses.append(history.history['val_loss'][-1])

            print(f"Fold {fold+1}: Accuracy={fold_accuracies[-1]:.4f}, Loss={fold_losses[-1]:.4f}")

        # Compute mean accuracy & loss for this hyperparameter set
        mean_accuracy = sum(fold_accuracies) / k
        mean_loss = sum(fold_losses) / k

        print(f"Mean Accuracy: {mean_accuracy:.4f}, Mean Loss: {mean_loss:.4f}")

        # Store results
        results.append((learning_rate, momentum, mean_accuracy, mean_loss))

        # Track the best hyperparameters
        if mean_accuracy > best_mean_accuracy:
            best_mean_accuracy = mean_accuracy
            best_hyperparams = (learning_rate, momentum)

    # Print total time taken
    total_time = time.time() - start_time
    print(f"\nTotal training time: {total_time:.2f} seconds")

    # Print best hyperparameters
    print(f"\nBest Hyperparameters: Learning Rate={best_hyperparams[0]}, Momentum={best_hyperparams[1]}")
    print(f"Best Mean Validation Accuracy: {best_mean_accuracy:.4f}")

    return results, best_hyperparams

# %%
##---------Type the code below this line------------------##
# Train
# uncomment to run cv again. It takes long time
train_model_cv(X_train, y_train, X_test, y_test)
# Out:
# Cross-validation training started...
#
# Evaluating Hyperparameters: Learning Rate=0.1, Momentum=0.8
#
# Training Fold 1/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.6369 - loss: 0.6502 - val_accuracy: 0.5067 - val_loss: 3.9724
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.7866 - loss: 0.4693 - val_accuracy: 0.5119 - val_loss: 2.8097
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8826 - loss: 0.2949 - val_accuracy: 0.8448 - val_loss: 0.3588
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9145 - loss: 0.2172 - val_accuracy: 0.6177 - val_loss: 3.0386
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9342 - loss: 0.1770 - val_accuracy: 0.8388 - val_loss: 0.3925
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9412 - loss: 0.1543 - val_accuracy: 0.7755 - val_loss: 0.7741
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9353 - loss: 0.1761 - val_accuracy: 0.5933 - val_loss: 4.2760
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9480 - loss: 0.1390 - val_accuracy: 0.8434 - val_loss: 0.4627
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 13s 26ms/step - accuracy: 0.9557 - loss: 0.1155 - val_accuracy: 0.8575 - val_loss: 0.4416
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9581 - loss: 0.1094 - val_accuracy: 0.7017 - val_loss: 1.8375
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9632 - loss: 0.0980 - val_accuracy: 0.7055 - val_loss: 1.6784
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9676 - loss: 0.0857 - val_accuracy: 0.8016 - val_loss: 0.7719
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9643 - loss: 0.0960 - val_accuracy: 0.5690 - val_loss: 2.7171
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9525 - loss: 0.1235 - val_accuracy: 0.5933 - val_loss: 4.7468
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9621 - loss: 0.1008 - val_accuracy: 0.7031 - val_loss: 2.6840
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9689 - loss: 0.0786 - val_accuracy: 0.8275 - val_loss: 0.7964
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9794 - loss: 0.0582 - val_accuracy: 0.7846 - val_loss: 1.1047
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9769 - loss: 0.0615 - val_accuracy: 0.8045 - val_loss: 1.0107
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9779 - loss: 0.0613 - val_accuracy: 0.8281 - val_loss: 0.7701
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9543 - loss: 0.1173 - val_accuracy: 0.7135 - val_loss: 1.6889
# Fold 1: Accuracy=0.7135, Loss=1.6889
#
# Training Fold 2/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6611 - loss: 0.6344 - val_accuracy: 0.6774 - val_loss: 0.7258
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8140 - loss: 0.4190 - val_accuracy: 0.7563 - val_loss: 0.5370
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8710 - loss: 0.3150 - val_accuracy: 0.8287 - val_loss: 0.4008
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9086 - loss: 0.2338 - val_accuracy: 0.8426 - val_loss: 0.3628
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9162 - loss: 0.2182 - val_accuracy: 0.8522 - val_loss: 0.3511
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9396 - loss: 0.1583 - val_accuracy: 0.6848 - val_loss: 1.5197
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9501 - loss: 0.1348 - val_accuracy: 0.7448 - val_loss: 0.9179
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9291 - loss: 0.1860 - val_accuracy: 0.7946 - val_loss: 0.5381
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9548 - loss: 0.1266 - val_accuracy: 0.8229 - val_loss: 0.6059
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9582 - loss: 0.1198 - val_accuracy: 0.7366 - val_loss: 1.0937
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9654 - loss: 0.0958 - val_accuracy: 0.5138 - val_loss: 13.6577
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9484 - loss: 0.1277 - val_accuracy: 0.6776 - val_loss: 2.2355
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9608 - loss: 0.0991 - val_accuracy: 0.6804 - val_loss: 1.6841
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9704 - loss: 0.0805 - val_accuracy: 0.8450 - val_loss: 0.4773
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9682 - loss: 0.0828 - val_accuracy: 0.7063 - val_loss: 1.9194
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9712 - loss: 0.0753 - val_accuracy: 0.5115 - val_loss: 5.4973
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9347 - loss: 0.1639 - val_accuracy: 0.5918 - val_loss: 5.1002
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9637 - loss: 0.0962 - val_accuracy: 0.6985 - val_loss: 2.5264
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9710 - loss: 0.0849 - val_accuracy: 0.8322 - val_loss: 0.6882
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9752 - loss: 0.0674 - val_accuracy: 0.7579 - val_loss: 1.6127
# Fold 2: Accuracy=0.7579, Loss=1.6127
#
# Training Fold 3/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6428 - loss: 0.6554 - val_accuracy: 0.5979 - val_loss: 0.7210
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8002 - loss: 0.4491 - val_accuracy: 0.7808 - val_loss: 0.4964
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8685 - loss: 0.3179 - val_accuracy: 0.6408 - val_loss: 0.9049
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8984 - loss: 0.2503 - val_accuracy: 0.6609 - val_loss: 1.3241
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9254 - loss: 0.1930 - val_accuracy: 0.6840 - val_loss: 0.8735
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9240 - loss: 0.2043 - val_accuracy: 0.8715 - val_loss: 0.3322
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9403 - loss: 0.1553 - val_accuracy: 0.8400 - val_loss: 0.4263
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9440 - loss: 0.1585 - val_accuracy: 0.5083 - val_loss: 5.7973
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9119 - loss: 0.2151 - val_accuracy: 0.6248 - val_loss: 5.3243
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.9462 - loss: 0.1356 - val_accuracy: 0.7715 - val_loss: 0.9346
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9557 - loss: 0.1143 - val_accuracy: 0.8561 - val_loss: 0.4177
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9573 - loss: 0.1119 - val_accuracy: 0.8137 - val_loss: 0.5850
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9619 - loss: 0.1044 - val_accuracy: 0.7219 - val_loss: 1.8288
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.9525 - loss: 0.1291 - val_accuracy: 0.7268 - val_loss: 1.5731
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9627 - loss: 0.1055 - val_accuracy: 0.7466 - val_loss: 1.5410
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9682 - loss: 0.0866 - val_accuracy: 0.6703 - val_loss: 2.3688
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9714 - loss: 0.0836 - val_accuracy: 0.8514 - val_loss: 0.5779
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 39ms/step - accuracy: 0.9752 - loss: 0.0666 - val_accuracy: 0.8159 - val_loss: 0.8947
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 30ms/step - accuracy: 0.9736 - loss: 0.0718 - val_accuracy: 0.6161 - val_loss: 4.2392
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 17ms/step - accuracy: 0.9747 - loss: 0.0719 - val_accuracy: 0.8456 - val_loss: 0.6827
# Fold 3: Accuracy=0.8456, Loss=0.6827
#
# Training Fold 4/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6029 - loss: 0.6853 - val_accuracy: 0.5513 - val_loss: 1.6606
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.7834 - loss: 0.4807 - val_accuracy: 0.5033 - val_loss: 2.3546
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8758 - loss: 0.3072 - val_accuracy: 0.5593 - val_loss: 1.5845
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9082 - loss: 0.2300 - val_accuracy: 0.8045 - val_loss: 0.4286
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9231 - loss: 0.2027 - val_accuracy: 0.7659 - val_loss: 0.7281
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9362 - loss: 0.1589 - val_accuracy: 0.7774 - val_loss: 0.8465
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9392 - loss: 0.1535 - val_accuracy: 0.8386 - val_loss: 0.4452
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9437 - loss: 0.1488 - val_accuracy: 0.7511 - val_loss: 0.6746
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9443 - loss: 0.1464 - val_accuracy: 0.5920 - val_loss: 4.6550
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9571 - loss: 0.1114 - val_accuracy: 0.8669 - val_loss: 0.4339
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9641 - loss: 0.0950 - val_accuracy: 0.7129 - val_loss: 1.7473
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9679 - loss: 0.0863 - val_accuracy: 0.8563 - val_loss: 0.5374
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9693 - loss: 0.0799 - val_accuracy: 0.7149 - val_loss: 1.8478
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9691 - loss: 0.0827 - val_accuracy: 0.6362 - val_loss: 2.7872
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9700 - loss: 0.0732 - val_accuracy: 0.7836 - val_loss: 1.2013
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9644 - loss: 0.0977 - val_accuracy: 0.5796 - val_loss: 6.0435
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9739 - loss: 0.0714 - val_accuracy: 0.8109 - val_loss: 0.8456
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9750 - loss: 0.0658 - val_accuracy: 0.6938 - val_loss: 2.2055
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9690 - loss: 0.0841 - val_accuracy: 0.7466 - val_loss: 1.5617
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9772 - loss: 0.0600 - val_accuracy: 0.8037 - val_loss: 1.0640
# Fold 4: Accuracy=0.8037, Loss=1.0640
#
# Training Fold 5/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6596 - loss: 0.6343 - val_accuracy: 0.5137 - val_loss: 2.4865
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8476 - loss: 0.3771 - val_accuracy: 0.6468 - val_loss: 1.1550
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9075 - loss: 0.2287 - val_accuracy: 0.7908 - val_loss: 0.4506
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9285 - loss: 0.1846 - val_accuracy: 0.7092 - val_loss: 0.8754
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8889 - loss: 0.2747 - val_accuracy: 0.6466 - val_loss: 2.1137
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9397 - loss: 0.1636 - val_accuracy: 0.8247 - val_loss: 0.4918
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9534 - loss: 0.1254 - val_accuracy: 0.5110 - val_loss: 6.7920
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9495 - loss: 0.1318 - val_accuracy: 0.8116 - val_loss: 0.5630
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9621 - loss: 0.0986 - val_accuracy: 0.6600 - val_loss: 1.8680
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9510 - loss: 0.1329 - val_accuracy: 0.8466 - val_loss: 0.4285
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.9607 - loss: 0.1007 - val_accuracy: 0.8217 - val_loss: 0.5931
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9674 - loss: 0.0837 - val_accuracy: 0.8544 - val_loss: 0.4915
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9597 - loss: 0.1066 - val_accuracy: 0.6323 - val_loss: 4.4088
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9655 - loss: 0.0987 - val_accuracy: 0.8221 - val_loss: 0.7290
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9691 - loss: 0.0830 - val_accuracy: 0.6717 - val_loss: 2.1266
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9694 - loss: 0.0848 - val_accuracy: 0.8468 - val_loss: 0.6303
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9682 - loss: 0.0877 - val_accuracy: 0.6771 - val_loss: 3.2464
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9627 - loss: 0.0977 - val_accuracy: 0.6966 - val_loss: 2.3912
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9715 - loss: 0.0783 - val_accuracy: 0.7335 - val_loss: 1.0279
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9654 - loss: 0.0964 - val_accuracy: 0.6894 - val_loss: 3.1025
# Fold 5: Accuracy=0.6894, Loss=3.1025
# Mean Accuracy: 0.7620, Mean Loss: 1.6302
#
# Evaluating Hyperparameters: Learning Rate=0.1, Momentum=0.9
#
# Training Fold 1/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.6321 - loss: 0.6924 - val_accuracy: 0.4985 - val_loss: 4.1772
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.7724 - loss: 0.4831 - val_accuracy: 0.6434 - val_loss: 0.6939
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8694 - loss: 0.3197 - val_accuracy: 0.8107 - val_loss: 0.4064
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9170 - loss: 0.2133 - val_accuracy: 0.6222 - val_loss: 0.8543
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9297 - loss: 0.1886 - val_accuracy: 0.7071 - val_loss: 0.9173
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9382 - loss: 0.1631 - val_accuracy: 0.7551 - val_loss: 0.7758
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9416 - loss: 0.1597 - val_accuracy: 0.7129 - val_loss: 1.0909
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9432 - loss: 0.1486 - val_accuracy: 0.7320 - val_loss: 0.7917
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9415 - loss: 0.1491 - val_accuracy: 0.5298 - val_loss: 4.2353
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9516 - loss: 0.1276 - val_accuracy: 0.6167 - val_loss: 1.1801
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9548 - loss: 0.1207 - val_accuracy: 0.8249 - val_loss: 0.5191
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9664 - loss: 0.0909 - val_accuracy: 0.6041 - val_loss: 1.6650
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9570 - loss: 0.1145 - val_accuracy: 0.8386 - val_loss: 0.4506
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9641 - loss: 0.0942 - val_accuracy: 0.5563 - val_loss: 3.0649
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9669 - loss: 0.0890 - val_accuracy: 0.8565 - val_loss: 0.4290
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9689 - loss: 0.0796 - val_accuracy: 0.7282 - val_loss: 1.4959
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9678 - loss: 0.0838 - val_accuracy: 0.6529 - val_loss: 2.8644
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9706 - loss: 0.0830 - val_accuracy: 0.5880 - val_loss: 1.5346
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9492 - loss: 0.1224 - val_accuracy: 0.7282 - val_loss: 1.3961
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9745 - loss: 0.0664 - val_accuracy: 0.8452 - val_loss: 0.5451
# Fold 1: Accuracy=0.8452, Loss=0.5451
#
# Training Fold 2/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6343 - loss: 0.6727 - val_accuracy: 0.6171 - val_loss: 0.8543
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8475 - loss: 0.3705 - val_accuracy: 0.6848 - val_loss: 0.6806
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8854 - loss: 0.2777 - val_accuracy: 0.8709 - val_loss: 0.3005
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9176 - loss: 0.2111 - val_accuracy: 0.7089 - val_loss: 0.8705
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9361 - loss: 0.1665 - val_accuracy: 0.6977 - val_loss: 1.0436
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9416 - loss: 0.1534 - val_accuracy: 0.8209 - val_loss: 0.4687
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9514 - loss: 0.1329 - val_accuracy: 0.8396 - val_loss: 0.5129
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9535 - loss: 0.1209 - val_accuracy: 0.7256 - val_loss: 0.6858
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9546 - loss: 0.1228 - val_accuracy: 0.7438 - val_loss: 0.9931
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9640 - loss: 0.1012 - val_accuracy: 0.6954 - val_loss: 2.0037
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9611 - loss: 0.1085 - val_accuracy: 0.6163 - val_loss: 3.4011
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9553 - loss: 0.1186 - val_accuracy: 0.6958 - val_loss: 1.4524
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9703 - loss: 0.0805 - val_accuracy: 0.5150 - val_loss: 7.7242
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9444 - loss: 0.1485 - val_accuracy: 0.7059 - val_loss: 1.6294
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9697 - loss: 0.0825 - val_accuracy: 0.8663 - val_loss: 0.4565
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9744 - loss: 0.0724 - val_accuracy: 0.8027 - val_loss: 0.8740
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9634 - loss: 0.0972 - val_accuracy: 0.5079 - val_loss: 4.8344
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9153 - loss: 0.2185 - val_accuracy: 0.5692 - val_loss: 7.8860
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9661 - loss: 0.0923 - val_accuracy: 0.7918 - val_loss: 0.8351
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9713 - loss: 0.0776 - val_accuracy: 0.6722 - val_loss: 2.4481
# Fold 2: Accuracy=0.6722, Loss=2.4481
#
# Training Fold 3/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.6186 - loss: 0.6896 - val_accuracy: 0.5154 - val_loss: 0.9300
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8377 - loss: 0.3694 - val_accuracy: 0.6457 - val_loss: 0.6564
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8991 - loss: 0.2514 - val_accuracy: 0.8807 - val_loss: 0.2983
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9233 - loss: 0.1944 - val_accuracy: 0.6027 - val_loss: 2.3579
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9262 - loss: 0.1918 - val_accuracy: 0.8396 - val_loss: 0.3714
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9412 - loss: 0.1574 - val_accuracy: 0.7400 - val_loss: 1.2313
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9484 - loss: 0.1334 - val_accuracy: 0.7567 - val_loss: 0.6704
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9500 - loss: 0.1371 - val_accuracy: 0.7446 - val_loss: 1.4246
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9396 - loss: 0.1580 - val_accuracy: 0.6617 - val_loss: 1.7629
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9514 - loss: 0.1313 - val_accuracy: 0.8659 - val_loss: 0.3868
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9570 - loss: 0.1100 - val_accuracy: 0.8569 - val_loss: 0.3750
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9669 - loss: 0.0908 - val_accuracy: 0.8187 - val_loss: 0.7036
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9648 - loss: 0.0953 - val_accuracy: 0.7434 - val_loss: 0.7712
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9672 - loss: 0.0908 - val_accuracy: 0.7884 - val_loss: 0.5944
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9559 - loss: 0.1136 - val_accuracy: 0.6687 - val_loss: 3.8417
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9564 - loss: 0.1120 - val_accuracy: 0.7342 - val_loss: 1.6365
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9658 - loss: 0.0865 - val_accuracy: 0.8267 - val_loss: 0.8048
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9620 - loss: 0.1011 - val_accuracy: 0.6529 - val_loss: 2.8231
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9683 - loss: 0.0826 - val_accuracy: 0.8219 - val_loss: 0.6606
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9726 - loss: 0.0737 - val_accuracy: 0.5983 - val_loss: 4.0903
# Fold 3: Accuracy=0.5983, Loss=4.0903
#
# Training Fold 4/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.6538 - loss: 0.6411 - val_accuracy: 0.5091 - val_loss: 3.2900
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8490 - loss: 0.3669 - val_accuracy: 0.6872 - val_loss: 1.5234
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8811 - loss: 0.2974 - val_accuracy: 0.7715 - val_loss: 0.5911
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9056 - loss: 0.2375 - val_accuracy: 0.8460 - val_loss: 0.3655
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9235 - loss: 0.1950 - val_accuracy: 0.7745 - val_loss: 0.5087
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9235 - loss: 0.1972 - val_accuracy: 0.7296 - val_loss: 1.1133
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9478 - loss: 0.1430 - val_accuracy: 0.7657 - val_loss: 0.7973
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9234 - loss: 0.1915 - val_accuracy: 0.5888 - val_loss: 3.0246
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8296 - loss: 0.3989 - val_accuracy: 0.5666 - val_loss: 2.5340
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8891 - loss: 0.2883 - val_accuracy: 0.5292 - val_loss: 3.2827
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9246 - loss: 0.1842 - val_accuracy: 0.5784 - val_loss: 5.7924
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9510 - loss: 0.1239 - val_accuracy: 0.7242 - val_loss: 1.7648
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9616 - loss: 0.0989 - val_accuracy: 0.8609 - val_loss: 0.4422
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9624 - loss: 0.0990 - val_accuracy: 0.7378 - val_loss: 1.2902
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9679 - loss: 0.0858 - val_accuracy: 0.8004 - val_loss: 0.9177
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9682 - loss: 0.0851 - val_accuracy: 0.7410 - val_loss: 1.4441
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9664 - loss: 0.0895 - val_accuracy: 0.5354 - val_loss: 3.0179
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9450 - loss: 0.1407 - val_accuracy: 0.6842 - val_loss: 2.4159
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9644 - loss: 0.0907 - val_accuracy: 0.7095 - val_loss: 2.0461
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9650 - loss: 0.0988 - val_accuracy: 0.8029 - val_loss: 0.7094
# Fold 4: Accuracy=0.8029, Loss=0.7094
#
# Training Fold 5/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6383 - loss: 0.6654 - val_accuracy: 0.6446 - val_loss: 1.0127
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8618 - loss: 0.3401 - val_accuracy: 0.8319 - val_loss: 0.3901
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9013 - loss: 0.2640 - val_accuracy: 0.8070 - val_loss: 0.4136
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9139 - loss: 0.2257 - val_accuracy: 0.8604 - val_loss: 0.3218
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9349 - loss: 0.1722 - val_accuracy: 0.5106 - val_loss: 3.5358
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9431 - loss: 0.1571 - val_accuracy: 0.8450 - val_loss: 0.3893
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9430 - loss: 0.1579 - val_accuracy: 0.5151 - val_loss: 5.7724
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9420 - loss: 0.1557 - val_accuracy: 0.6472 - val_loss: 1.2519
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9599 - loss: 0.1133 - val_accuracy: 0.5307 - val_loss: 4.8881
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9506 - loss: 0.1237 - val_accuracy: 0.8032 - val_loss: 0.7119
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9617 - loss: 0.1045 - val_accuracy: 0.7402 - val_loss: 0.8430
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9657 - loss: 0.0882 - val_accuracy: 0.8502 - val_loss: 0.4444
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9703 - loss: 0.0768 - val_accuracy: 0.7432 - val_loss: 0.9192
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9697 - loss: 0.0784 - val_accuracy: 0.5900 - val_loss: 3.2713
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9622 - loss: 0.1015 - val_accuracy: 0.8508 - val_loss: 0.4472
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9804 - loss: 0.0562 - val_accuracy: 0.7179 - val_loss: 2.1250
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9718 - loss: 0.0733 - val_accuracy: 0.6869 - val_loss: 2.2674
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9761 - loss: 0.0695 - val_accuracy: 0.8384 - val_loss: 0.6578
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9681 - loss: 0.0866 - val_accuracy: 0.6564 - val_loss: 1.6594
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9743 - loss: 0.0695 - val_accuracy: 0.5448 - val_loss: 3.7307
# Fold 5: Accuracy=0.5448, Loss=3.7307
# Mean Accuracy: 0.6927, Mean Loss: 2.3047
#
# Evaluating Hyperparameters: Learning Rate=0.1, Momentum=0.95
#
# Training Fold 1/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 18ms/step - accuracy: 0.6393 - loss: 0.6645 - val_accuracy: 0.4983 - val_loss: 5.6720
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8526 - loss: 0.3483 - val_accuracy: 0.5047 - val_loss: 1.6799
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8823 - loss: 0.2848 - val_accuracy: 0.6079 - val_loss: 0.8797
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9099 - loss: 0.2414 - val_accuracy: 0.5101 - val_loss: 4.3344
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9025 - loss: 0.2417 - val_accuracy: 0.8689 - val_loss: 0.3185
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9203 - loss: 0.2036 - val_accuracy: 0.5011 - val_loss: 2.7866
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8932 - loss: 0.2586 - val_accuracy: 0.7970 - val_loss: 0.5089
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9328 - loss: 0.1702 - val_accuracy: 0.6744 - val_loss: 2.1383
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9500 - loss: 0.1295 - val_accuracy: 0.8047 - val_loss: 0.5473
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9528 - loss: 0.1246 - val_accuracy: 0.8542 - val_loss: 0.3855
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9584 - loss: 0.1092 - val_accuracy: 0.7774 - val_loss: 0.7244
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9588 - loss: 0.1063 - val_accuracy: 0.8426 - val_loss: 0.3998
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9597 - loss: 0.1093 - val_accuracy: 0.5601 - val_loss: 4.7952
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9566 - loss: 0.1148 - val_accuracy: 0.7615 - val_loss: 1.0204
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9593 - loss: 0.1057 - val_accuracy: 0.7866 - val_loss: 0.5972
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9470 - loss: 0.1389 - val_accuracy: 0.8346 - val_loss: 0.4764
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9670 - loss: 0.0871 - val_accuracy: 0.5334 - val_loss: 3.8434
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9618 - loss: 0.1064 - val_accuracy: 0.8259 - val_loss: 0.7887
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9598 - loss: 0.1128 - val_accuracy: 0.8047 - val_loss: 0.5594
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9661 - loss: 0.0971 - val_accuracy: 0.5154 - val_loss: 4.8512
# Fold 1: Accuracy=0.5154, Loss=4.8512
#
# Training Fold 2/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6473 - loss: 0.6560 - val_accuracy: 0.8635 - val_loss: 0.3482
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.8825 - loss: 0.2940 - val_accuracy: 0.8637 - val_loss: 0.3473
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.8811 - loss: 0.3169 - val_accuracy: 0.7601 - val_loss: 0.5495
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 15ms/step - accuracy: 0.9279 - loss: 0.1965 - val_accuracy: 0.7954 - val_loss: 0.4395
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9227 - loss: 0.2069 - val_accuracy: 0.7840 - val_loss: 0.4761
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9345 - loss: 0.1795 - val_accuracy: 0.8707 - val_loss: 0.3252
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9514 - loss: 0.1384 - val_accuracy: 0.8585 - val_loss: 0.3814
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9523 - loss: 0.1415 - val_accuracy: 0.8486 - val_loss: 0.4859
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9525 - loss: 0.1359 - val_accuracy: 0.8641 - val_loss: 0.3760
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9595 - loss: 0.1154 - val_accuracy: 0.8171 - val_loss: 0.4402
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9212 - loss: 0.2266 - val_accuracy: 0.7928 - val_loss: 0.6589
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9579 - loss: 0.1325 - val_accuracy: 0.8215 - val_loss: 0.4627
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9544 - loss: 0.1333 - val_accuracy: 0.7055 - val_loss: 2.4675
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9478 - loss: 0.1661 - val_accuracy: 0.8538 - val_loss: 0.3763
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9652 - loss: 0.1047 - val_accuracy: 0.8063 - val_loss: 0.6794
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9655 - loss: 0.1096 - val_accuracy: 0.6940 - val_loss: 0.7226
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9502 - loss: 0.1438 - val_accuracy: 0.7115 - val_loss: 1.5233
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9640 - loss: 0.1125 - val_accuracy: 0.7235 - val_loss: 0.8464
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.9525 - loss: 0.1361 - val_accuracy: 0.6360 - val_loss: 1.5477
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9641 - loss: 0.1203 - val_accuracy: 0.5874 - val_loss: 1.8536
# Fold 2: Accuracy=0.5874, Loss=1.8536
#
# Training Fold 3/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.6530 - loss: 0.6644 - val_accuracy: 0.6151 - val_loss: 0.7088
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8457 - loss: 0.3726 - val_accuracy: 0.7657 - val_loss: 0.5233
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9041 - loss: 0.2433 - val_accuracy: 0.8163 - val_loss: 0.4017
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.9285 - loss: 0.1893 - val_accuracy: 0.7912 - val_loss: 0.5719
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9351 - loss: 0.1695 - val_accuracy: 0.7165 - val_loss: 0.8017
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9492 - loss: 0.1436 - val_accuracy: 0.8207 - val_loss: 0.5122
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9458 - loss: 0.1428 - val_accuracy: 0.7529 - val_loss: 0.7825
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9507 - loss: 0.1325 - val_accuracy: 0.6579 - val_loss: 1.2171
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9509 - loss: 0.1315 - val_accuracy: 0.8571 - val_loss: 0.4013
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9615 - loss: 0.1072 - val_accuracy: 0.8275 - val_loss: 0.4708
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9524 - loss: 0.1263 - val_accuracy: 0.8263 - val_loss: 0.4866
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9519 - loss: 0.1227 - val_accuracy: 0.7490 - val_loss: 1.0655
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9597 - loss: 0.1207 - val_accuracy: 0.5774 - val_loss: 2.6608
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9441 - loss: 0.1542 - val_accuracy: 0.6718 - val_loss: 0.9349
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9683 - loss: 0.0905 - val_accuracy: 0.7496 - val_loss: 0.9442
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9631 - loss: 0.0943 - val_accuracy: 0.7639 - val_loss: 0.7829
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9717 - loss: 0.0791 - val_accuracy: 0.7061 - val_loss: 0.9091
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9555 - loss: 0.1161 - val_accuracy: 0.8478 - val_loss: 0.4007
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9572 - loss: 0.1125 - val_accuracy: 0.7414 - val_loss: 1.4413
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9733 - loss: 0.0715 - val_accuracy: 0.6948 - val_loss: 1.8073
# Fold 3: Accuracy=0.6948, Loss=1.8073
#
# Training Fold 4/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.6698 - loss: 0.6464 - val_accuracy: 0.5348 - val_loss: 2.3153
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.7976 - loss: 0.4396 - val_accuracy: 0.6995 - val_loss: 0.7301
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8995 - loss: 0.2562 - val_accuracy: 0.6224 - val_loss: 3.1040
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8943 - loss: 0.2729 - val_accuracy: 0.7398 - val_loss: 0.6912
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9246 - loss: 0.1998 - val_accuracy: 0.5796 - val_loss: 2.1264
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9325 - loss: 0.1780 - val_accuracy: 0.7717 - val_loss: 0.5478
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9485 - loss: 0.1441 - val_accuracy: 0.8283 - val_loss: 0.4179
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9582 - loss: 0.1190 - val_accuracy: 0.8273 - val_loss: 0.6352
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9296 - loss: 0.1950 - val_accuracy: 0.8047 - val_loss: 0.5843
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9519 - loss: 0.1286 - val_accuracy: 0.6860 - val_loss: 1.3847
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9505 - loss: 0.1421 - val_accuracy: 0.5274 - val_loss: 0.8753
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8763 - loss: 0.2677 - val_accuracy: 0.8476 - val_loss: 0.4765
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9670 - loss: 0.0942 - val_accuracy: 0.5230 - val_loss: 8.8207
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.9353 - loss: 0.1728 - val_accuracy: 0.8667 - val_loss: 0.3416
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9644 - loss: 0.1040 - val_accuracy: 0.8635 - val_loss: 0.3840
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9666 - loss: 0.0874 - val_accuracy: 0.8526 - val_loss: 0.5217
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9659 - loss: 0.0977 - val_accuracy: 0.8400 - val_loss: 0.7824
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9641 - loss: 0.1007 - val_accuracy: 0.7402 - val_loss: 1.3798
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9545 - loss: 0.1283 - val_accuracy: 0.8075 - val_loss: 0.8341
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9714 - loss: 0.0734 - val_accuracy: 0.8524 - val_loss: 0.4944
# Fold 4: Accuracy=0.8524, Loss=0.4944
#
# Training Fold 5/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.6967 - loss: 0.6055 - val_accuracy: 0.7082 - val_loss: 0.8602
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8627 - loss: 0.3281 - val_accuracy: 0.7988 - val_loss: 0.4161
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9200 - loss: 0.2138 - val_accuracy: 0.5032 - val_loss: 5.4272
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9061 - loss: 0.2513 - val_accuracy: 0.7249 - val_loss: 0.8098
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9192 - loss: 0.2098 - val_accuracy: 0.7223 - val_loss: 0.7781
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9423 - loss: 0.1573 - val_accuracy: 0.8335 - val_loss: 0.3824
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9414 - loss: 0.1585 - val_accuracy: 0.7482 - val_loss: 0.8422
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9412 - loss: 0.1654 - val_accuracy: 0.8454 - val_loss: 0.4245
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9530 - loss: 0.1248 - val_accuracy: 0.7546 - val_loss: 0.6999
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.9560 - loss: 0.1195 - val_accuracy: 0.8524 - val_loss: 0.4545
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9653 - loss: 0.0951 - val_accuracy: 0.8396 - val_loss: 0.5018
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9622 - loss: 0.1083 - val_accuracy: 0.8538 - val_loss: 0.4488
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9683 - loss: 0.0903 - val_accuracy: 0.8480 - val_loss: 0.4674
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9634 - loss: 0.0925 - val_accuracy: 0.8452 - val_loss: 0.4836
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9662 - loss: 0.0869 - val_accuracy: 0.8157 - val_loss: 0.5910
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9526 - loss: 0.1350 - val_accuracy: 0.6620 - val_loss: 1.8912
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9657 - loss: 0.1006 - val_accuracy: 0.7853 - val_loss: 0.7504
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - accuracy: 0.9638 - loss: 0.0985 - val_accuracy: 0.7649 - val_loss: 1.1150
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9696 - loss: 0.0829 - val_accuracy: 0.7275 - val_loss: 1.3154
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9704 - loss: 0.0795 - val_accuracy: 0.6542 - val_loss: 1.8897
# Fold 5: Accuracy=0.6542, Loss=1.8897
# Mean Accuracy: 0.6609, Mean Loss: 2.1792
#
# Evaluating Hyperparameters: Learning Rate=0.005, Momentum=0.8
#
# Training Fold 1/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - accuracy: 0.6820 - loss: 0.5971 - val_accuracy: 0.8474 - val_loss: 0.4056
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8423 - loss: 0.3679 - val_accuracy: 0.5686 - val_loss: 0.7105
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8595 - loss: 0.3345 - val_accuracy: 0.8380 - val_loss: 0.3747
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8867 - loss: 0.2772 - val_accuracy: 0.6204 - val_loss: 0.8616
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8576 - loss: 0.3265 - val_accuracy: 0.5332 - val_loss: 1.4123
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8772 - loss: 0.3037 - val_accuracy: 0.7065 - val_loss: 1.1204
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9070 - loss: 0.2315 - val_accuracy: 0.6958 - val_loss: 0.6216
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9086 - loss: 0.2267 - val_accuracy: 0.6085 - val_loss: 1.2942
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9037 - loss: 0.2401 - val_accuracy: 0.5449 - val_loss: 5.6436
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8707 - loss: 0.3033 - val_accuracy: 0.8207 - val_loss: 0.3957
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9264 - loss: 0.1989 - val_accuracy: 0.7117 - val_loss: 1.0721
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9419 - loss: 0.1521 - val_accuracy: 0.8292 - val_loss: 0.4630
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9384 - loss: 0.1634 - val_accuracy: 0.6461 - val_loss: 1.8749
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9526 - loss: 0.1232 - val_accuracy: 0.6173 - val_loss: 2.5238
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.9523 - loss: 0.1225 - val_accuracy: 0.7141 - val_loss: 0.7916
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9420 - loss: 0.1525 - val_accuracy: 0.5401 - val_loss: 4.5418
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9638 - loss: 0.0956 - val_accuracy: 0.7553 - val_loss: 0.9838
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9708 - loss: 0.0766 - val_accuracy: 0.6196 - val_loss: 2.0831
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9643 - loss: 0.0917 - val_accuracy: 0.8336 - val_loss: 0.5919
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9696 - loss: 0.0795 - val_accuracy: 0.7890 - val_loss: 0.9401
# Fold 1: Accuracy=0.7890, Loss=0.9401
#
# Training Fold 2/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 18ms/step - accuracy: 0.6980 - loss: 0.5819 - val_accuracy: 0.5768 - val_loss: 0.7119
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8634 - loss: 0.3301 - val_accuracy: 0.7810 - val_loss: 0.5078
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.8538 - loss: 0.3463 - val_accuracy: 0.6900 - val_loss: 0.6571
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8937 - loss: 0.2569 - val_accuracy: 0.6254 - val_loss: 1.0766
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.8877 - loss: 0.2770 - val_accuracy: 0.6198 - val_loss: 0.7390
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8587 - loss: 0.3292 - val_accuracy: 0.8651 - val_loss: 0.3304
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 18ms/step - accuracy: 0.9118 - loss: 0.2244 - val_accuracy: 0.6206 - val_loss: 1.3493
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.8942 - loss: 0.2643 - val_accuracy: 0.8601 - val_loss: 0.3374
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9219 - loss: 0.1979 - val_accuracy: 0.5987 - val_loss: 0.9178
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 17ms/step - accuracy: 0.9257 - loss: 0.1900 - val_accuracy: 0.6473 - val_loss: 2.1300
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9439 - loss: 0.1448 - val_accuracy: 0.8673 - val_loss: 0.3253
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9482 - loss: 0.1319 - val_accuracy: 0.7085 - val_loss: 1.2258
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9535 - loss: 0.1257 - val_accuracy: 0.8603 - val_loss: 0.3597
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9611 - loss: 0.1116 - val_accuracy: 0.7637 - val_loss: 0.8818
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9621 - loss: 0.1078 - val_accuracy: 0.6804 - val_loss: 1.6062
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9679 - loss: 0.0901 - val_accuracy: 0.8426 - val_loss: 0.4496
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9690 - loss: 0.0831 - val_accuracy: 0.8550 - val_loss: 0.5245
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 21ms/step - accuracy: 0.9703 - loss: 0.0770 - val_accuracy: 0.7155 - val_loss: 1.8433
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9655 - loss: 0.1063 - val_accuracy: 0.8191 - val_loss: 0.6275
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9740 - loss: 0.0722 - val_accuracy: 0.7079 - val_loss: 1.3394
# Fold 2: Accuracy=0.7079, Loss=1.3394
#
# Training Fold 3/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.6655 - loss: 0.6225 - val_accuracy: 0.5621 - val_loss: 0.7307
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8242 - loss: 0.4019 - val_accuracy: 0.7308 - val_loss: 0.5837
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.8598 - loss: 0.3370 - val_accuracy: 0.8412 - val_loss: 0.3840
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8891 - loss: 0.2698 - val_accuracy: 0.7013 - val_loss: 0.5650
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9155 - loss: 0.2135 - val_accuracy: 0.6270 - val_loss: 1.2851
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9076 - loss: 0.2367 - val_accuracy: 0.8711 - val_loss: 0.3151
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9319 - loss: 0.1735 - val_accuracy: 0.7454 - val_loss: 0.6605
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9116 - loss: 0.2262 - val_accuracy: 0.7607 - val_loss: 0.6955
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.9375 - loss: 0.1671 - val_accuracy: 0.5294 - val_loss: 8.4519
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9263 - loss: 0.1981 - val_accuracy: 0.8087 - val_loss: 0.4790
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9446 - loss: 0.1450 - val_accuracy: 0.6264 - val_loss: 2.5772
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9401 - loss: 0.1571 - val_accuracy: 0.5657 - val_loss: 4.4314
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.9544 - loss: 0.1170 - val_accuracy: 0.5222 - val_loss: 4.3642
# Epoch 14/20
# ...
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9330 - loss: 0.1735 - val_accuracy: 0.6657 - val_loss: 1.4741
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9512 - loss: 0.1240 - val_accuracy: 0.7502 - val_loss: 0.8079
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9601 - loss: 0.1045 - val_accuracy: 0.7460 - val_loss: 1.0909
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9597 - loss: 0.1029 - val_accuracy: 0.7940 - val_loss: 0.6989
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9581 - loss: 0.1160 - val_accuracy: 0.8524 - val_loss: 0.4040
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 17ms/step - accuracy: 0.9598 - loss: 0.1055 - val_accuracy: 0.7954 - val_loss: 0.7334
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9671 - loss: 0.0868 - val_accuracy: 0.8060 - val_loss: 0.7796
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9727 - loss: 0.0742 - val_accuracy: 0.7755 - val_loss: 1.0291
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9766 - loss: 0.0640 - val_accuracy: 0.7958 - val_loss: 1.3371
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9713 - loss: 0.0774 - val_accuracy: 0.8392 - val_loss: 0.6535
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9779 - loss: 0.0634 - val_accuracy: 0.7215 - val_loss: 1.7913
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.9785 - loss: 0.0563 - val_accuracy: 0.7558 - val_loss: 1.1405
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9685 - loss: 0.0820 - val_accuracy: 0.6263 - val_loss: 2.4593
# Fold 5: Accuracy=0.6263, Loss=2.4593
# Mean Accuracy: 0.7438, Mean Loss: 1.5156
#
# Evaluating Hyperparameters: Learning Rate=0.01, Momentum=0.95
#
# Training Fold 1/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 23ms/step - accuracy: 0.7304 - loss: 0.5388 - val_accuracy: 0.6005 - val_loss: 1.3272
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8780 - loss: 0.2955 - val_accuracy: 0.5045 - val_loss: 2.9992
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8995 - loss: 0.2540 - val_accuracy: 0.7203 - val_loss: 0.5673
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9031 - loss: 0.2445 - val_accuracy: 0.8530 - val_loss: 0.3424
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9325 - loss: 0.1800 - val_accuracy: 0.5527 - val_loss: 3.3317
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9270 - loss: 0.1868 - val_accuracy: 0.8601 - val_loss: 0.3418
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9551 - loss: 0.1207 - val_accuracy: 0.7017 - val_loss: 1.3703
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9484 - loss: 0.1360 - val_accuracy: 0.7912 - val_loss: 0.6173
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9469 - loss: 0.1414 - val_accuracy: 0.8119 - val_loss: 0.4994
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9511 - loss: 0.1309 - val_accuracy: 0.7998 - val_loss: 0.7237
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9583 - loss: 0.1110 - val_accuracy: 0.8514 - val_loss: 0.4566
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9572 - loss: 0.1129 - val_accuracy: 0.6521 - val_loss: 2.7680
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9603 - loss: 0.1022 - val_accuracy: 0.8400 - val_loss: 0.5246
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9593 - loss: 0.1117 - val_accuracy: 0.7613 - val_loss: 1.1370
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9686 - loss: 0.0836 - val_accuracy: 0.8324 - val_loss: 0.6273
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9738 - loss: 0.0750 - val_accuracy: 0.8273 - val_loss: 0.7545
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9737 - loss: 0.0700 - val_accuracy: 0.7300 - val_loss: 1.5567
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9728 - loss: 0.0758 - val_accuracy: 0.8201 - val_loss: 0.8250
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.9730 - loss: 0.0754 - val_accuracy: 0.7830 - val_loss: 1.0871
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9713 - loss: 0.0764 - val_accuracy: 0.8450 - val_loss: 0.5894
# Fold 1: Accuracy=0.8450, Loss=0.5894
#
# Training Fold 2/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.7066 - loss: 0.5739 - val_accuracy: 0.7003 - val_loss: 0.5768
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.8594 - loss: 0.3394 - val_accuracy: 0.7645 - val_loss: 0.5463
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9007 - loss: 0.2533 - val_accuracy: 0.8448 - val_loss: 0.3530
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8840 - loss: 0.2850 - val_accuracy: 0.7025 - val_loss: 0.6105
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.9037 - loss: 0.2473 - val_accuracy: 0.6924 - val_loss: 1.5691
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9282 - loss: 0.1912 - val_accuracy: 0.6615 - val_loss: 2.0269
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9321 - loss: 0.1704 - val_accuracy: 0.7681 - val_loss: 0.6430
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9421 - loss: 0.1504 - val_accuracy: 0.6649 - val_loss: 1.8186
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9568 - loss: 0.1247 - val_accuracy: 0.8512 - val_loss: 0.4913
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9556 - loss: 0.1110 - val_accuracy: 0.7996 - val_loss: 0.6457
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9517 - loss: 0.1275 - val_accuracy: 0.6029 - val_loss: 2.7901
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9618 - loss: 0.0990 - val_accuracy: 0.8546 - val_loss: 0.5046
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9641 - loss: 0.0958 - val_accuracy: 0.8181 - val_loss: 0.8273
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9628 - loss: 0.1001 - val_accuracy: 0.6697 - val_loss: 2.4717
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9633 - loss: 0.0982 - val_accuracy: 0.7986 - val_loss: 0.8688
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9673 - loss: 0.0879 - val_accuracy: 0.8233 - val_loss: 0.6664
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9731 - loss: 0.0734 - val_accuracy: 0.8360 - val_loss: 0.6068
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9717 - loss: 0.0761 - val_accuracy: 0.8575 - val_loss: 0.5073
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9701 - loss: 0.0809 - val_accuracy: 0.5838 - val_loss: 3.6588
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9612 - loss: 0.1040 - val_accuracy: 0.6836 - val_loss: 1.7359
# Fold 2: Accuracy=0.6836, Loss=1.7359
#
# Training Fold 3/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.7072 - loss: 0.5643 - val_accuracy: 0.7679 - val_loss: 0.4845
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.8728 - loss: 0.3088 - val_accuracy: 0.5115 - val_loss: 2.2288
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.8939 - loss: 0.2608 - val_accuracy: 0.6017 - val_loss: 1.3355
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8950 - loss: 0.2612 - val_accuracy: 0.8426 - val_loss: 0.3593
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9284 - loss: 0.1858 - val_accuracy: 0.5983 - val_loss: 1.8575
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9333 - loss: 0.1691 - val_accuracy: 0.8683 - val_loss: 0.3315
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9406 - loss: 0.1566 - val_accuracy: 0.7282 - val_loss: 1.1202
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 23ms/step - accuracy: 0.9486 - loss: 0.1381 - val_accuracy: 0.7386 - val_loss: 0.9950
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9572 - loss: 0.1109 - val_accuracy: 0.8049 - val_loss: 0.6825
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9603 - loss: 0.1067 - val_accuracy: 0.6830 - val_loss: 1.1588
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 21ms/step - accuracy: 0.9430 - loss: 0.1531 - val_accuracy: 0.5920 - val_loss: 4.1536
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9642 - loss: 0.0968 - val_accuracy: 0.8324 - val_loss: 0.6040
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9683 - loss: 0.0821 - val_accuracy: 0.6663 - val_loss: 3.2595
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9691 - loss: 0.0837 - val_accuracy: 0.6884 - val_loss: 1.6567
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 11s 19ms/step - accuracy: 0.9530 - loss: 0.1261 - val_accuracy: 0.6858 - val_loss: 1.9848
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9620 - loss: 0.0996 - val_accuracy: 0.8055 - val_loss: 0.5866
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9579 - loss: 0.1041 - val_accuracy: 0.8010 - val_loss: 0.7668
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9701 - loss: 0.0813 - val_accuracy: 0.8400 - val_loss: 0.5458
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9661 - loss: 0.0876 - val_accuracy: 0.7450 - val_loss: 1.3170
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 23ms/step - accuracy: 0.9797 - loss: 0.0593 - val_accuracy: 0.7663 - val_loss: 1.4660
# Fold 3: Accuracy=0.7663, Loss=1.4660
#
# Training Fold 4/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.7313 - loss: 0.5445 - val_accuracy: 0.8528 - val_loss: 0.3763
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8840 - loss: 0.2872 - val_accuracy: 0.6194 - val_loss: 0.9509
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9105 - loss: 0.2284 - val_accuracy: 0.6997 - val_loss: 0.9384
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9260 - loss: 0.1895 - val_accuracy: 0.8292 - val_loss: 0.4120
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9289 - loss: 0.1864 - val_accuracy: 0.8221 - val_loss: 0.4748
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9373 - loss: 0.1632 - val_accuracy: 0.7360 - val_loss: 1.0015
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9481 - loss: 0.1351 - val_accuracy: 0.8053 - val_loss: 0.7436
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9541 - loss: 0.1210 - val_accuracy: 0.8510 - val_loss: 0.4709
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9481 - loss: 0.1386 - val_accuracy: 0.6248 - val_loss: 2.6411
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9564 - loss: 0.1137 - val_accuracy: 0.7183 - val_loss: 1.3217
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9555 - loss: 0.1102 - val_accuracy: 0.7727 - val_loss: 0.8932
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.9651 - loss: 0.0927 - val_accuracy: 0.8657 - val_loss: 0.5072
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9647 - loss: 0.0979 - val_accuracy: 0.5732 - val_loss: 5.5120
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9609 - loss: 0.1044 - val_accuracy: 0.6495 - val_loss: 2.4217
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9663 - loss: 0.0873 - val_accuracy: 0.8376 - val_loss: 0.6609
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 22ms/step - accuracy: 0.9609 - loss: 0.1053 - val_accuracy: 0.8444 - val_loss: 0.5526
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9743 - loss: 0.0752 - val_accuracy: 0.7458 - val_loss: 1.9760
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9769 - loss: 0.0677 - val_accuracy: 0.8641 - val_loss: 0.3979
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9754 - loss: 0.0718 - val_accuracy: 0.8251 - val_loss: 0.6900
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9662 - loss: 0.0935 - val_accuracy: 0.5657 - val_loss: 5.2053
# Fold 4: Accuracy=0.5657, Loss=5.2053
#
# Training Fold 5/5...
# Model compiling
# Model training started
# Epoch 1/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - accuracy: 0.6919 - loss: 0.5856 - val_accuracy: 0.5143 - val_loss: 1.5731
# Epoch 2/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.8340 - loss: 0.3884 - val_accuracy: 0.6074 - val_loss: 0.7369
# Epoch 3/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.8510 - loss: 0.3412 - val_accuracy: 0.5500 - val_loss: 2.9966
# Epoch 4/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9037 - loss: 0.2448 - val_accuracy: 0.7934 - val_loss: 0.6777
# Epoch 5/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 25ms/step - accuracy: 0.9152 - loss: 0.2133 - val_accuracy: 0.7299 - val_loss: 0.7243
# Epoch 6/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9366 - loss: 0.1690 - val_accuracy: 0.8616 - val_loss: 0.3568
# Epoch 7/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 21ms/step - accuracy: 0.9448 - loss: 0.1504 - val_accuracy: 0.8500 - val_loss: 0.4225
# Epoch 8/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9567 - loss: 0.1182 - val_accuracy: 0.5735 - val_loss: 2.9517
# Epoch 9/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9511 - loss: 0.1232 - val_accuracy: 0.8325 - val_loss: 0.4674
# Epoch 10/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9532 - loss: 0.1271 - val_accuracy: 0.6962 - val_loss: 1.6308
# Epoch 11/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9578 - loss: 0.1157 - val_accuracy: 0.8303 - val_loss: 0.5687
# Epoch 12/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9595 - loss: 0.1043 - val_accuracy: 0.7476 - val_loss: 1.5151
# Epoch 13/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 10s 18ms/step - accuracy: 0.9621 - loss: 0.1073 - val_accuracy: 0.5213 - val_loss: 4.5299
# Epoch 14/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9568 - loss: 0.1138 - val_accuracy: 0.7516 - val_loss: 1.3108
# Epoch 15/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.9650 - loss: 0.0949 - val_accuracy: 0.8480 - val_loss: 0.5159
# Epoch 16/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9700 - loss: 0.0818 - val_accuracy: 0.7815 - val_loss: 1.0870
# Epoch 17/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.9668 - loss: 0.0871 - val_accuracy: 0.8390 - val_loss: 0.4179
# Epoch 18/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9645 - loss: 0.0959 - val_accuracy: 0.7257 - val_loss: 2.1030
# Epoch 19/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.9759 - loss: 0.0679 - val_accuracy: 0.6181 - val_loss: 2.8112
# Epoch 20/20
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - accuracy: 0.9699 - loss: 0.0777 - val_accuracy: 0.8480 - val_loss: 0.6056
# Fold 5: Accuracy=0.8480, Loss=0.6056
# Mean Accuracy: 0.7417, Mean Loss: 1.9205
#
# Total training time: 7094.64 seconds
#
# Best Hyperparameters: Learning Rate=0.01, Momentum=0.8
# Best Mean Validation Accuracy: 0.7875
# ([(0.1, 0.8, 0.7620031952857971, 1.6301677346229553),
#   (0.1, 0.9, 0.6926538825035096, 2.304709005355835),
#   (0.1, 0.95, 0.6608574390411377, 2.1792380571365357),
#   (0.005, 0.8, 0.7330873966217041, 1.456469225883484),
#   (0.005, 0.9, 0.7570248603820801, 1.318177080154419),
#   (0.005, 0.95, 0.7002106308937073, 2.403268575668335),
#   (0.01, 0.8, 0.7874634981155395, 0.9829612493515014),
#   (0.01, 0.9, 0.7437713861465454, 1.515638130903244),
#   (0.01, 0.95, 0.7417325019836426, 1.920451283454895)],
#  (0.01, 0.8))

# %% [markdown]
# Justify your choice of optimizers and regulizations used and the hyperparameters tuned

# %% [markdown]
# ##---------Type the answers below this line------------------##
# Why SGD?
#
# Why learning_rate & momentum
#
# Leanring Rate of
#
# why binary_crossentropy?
#
# binary_crossentropy is used because this is a binary classification problem with a sigmoid activation function, ensuring proper probability-based loss computation.

# %%
# final model based on cross validation

def train_model(model):
  model = compile_model(model, learning_rate=0.01, momentum=0.8)
  history = fit_model(model, X_train, y_train, X_test, y_test)
  return history

model = create_model()
history = train_model(model)
# Out:
# Model compiling
# Model training started
# Epoch 1/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.7019 - loss: 0.5691 - val_accuracy: 0.7884 - val_loss: 0.4569
# Epoch 2/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.8535 - loss: 0.3366 - val_accuracy: 0.5199 - val_loss: 2.1838
# Epoch 3/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8501 - loss: 0.3457 - val_accuracy: 0.6771 - val_loss: 0.6313
# Epoch 4/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.8874 - loss: 0.2828 - val_accuracy: 0.5716 - val_loss: 0.8617
# Epoch 5/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.8541 - loss: 0.3379 - val_accuracy: 0.6066 - val_loss: 0.7480
# Epoch 6/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.8950 - loss: 0.2599 - val_accuracy: 0.5963 - val_loss: 1.9578
# Epoch 7/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.9123 - loss: 0.2160 - val_accuracy: 0.8472 - val_loss: 0.3531
# Epoch 8/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9278 - loss: 0.1900 - val_accuracy: 0.8477 - val_loss: 0.3662
# Epoch 9/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9418 - loss: 0.1545 - val_accuracy: 0.6074 - val_loss: 2.9364
# Epoch 10/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9511 - loss: 0.1334 - val_accuracy: 0.7096 - val_loss: 1.3249
# Epoch 11/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9471 - loss: 0.1399 - val_accuracy: 0.7309 - val_loss: 1.1005
# Epoch 12/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9477 - loss: 0.1433 - val_accuracy: 0.7277 - val_loss: 1.3702
# Epoch 13/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9430 - loss: 0.1541 - val_accuracy: 0.6128 - val_loss: 2.7895
# Epoch 14/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9630 - loss: 0.1056 - val_accuracy: 0.7821 - val_loss: 0.7034
# Epoch 15/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 20ms/step - accuracy: 0.9655 - loss: 0.0928 - val_accuracy: 0.7392 - val_loss: 1.5328
# Epoch 16/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9713 - loss: 0.0774 - val_accuracy: 0.7271 - val_loss: 1.4864
# Epoch 17/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.9697 - loss: 0.0807 - val_accuracy: 0.7621 - val_loss: 1.0264
# Epoch 18/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9633 - loss: 0.0893 - val_accuracy: 0.7459 - val_loss: 1.6802
# Epoch 19/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9417 - loss: 0.1483 - val_accuracy: 0.6213 - val_loss: 3.1442
# Epoch 20/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9726 - loss: 0.0763 - val_accuracy: 0.8359 - val_loss: 0.5634

# %% [markdown]
# # 6. Test the model - 0.5 marks

# %%
##---------Type the code below this line------------------##
model.evaluate(X_test, y_test)
# Out:
# 776/776 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.8341 - loss: 0.5663
# [0.563435435295105, 0.8358533978462219]

# %% [markdown]
# # 7. Intermediate result  - Score: 1 mark
#
# 1. Plot the training and validation accuracy history.
# 2. Plot the training and validation loss history.
# 3. Report the testing accuracy and loss.
# 4. Show Confusion Matrix for testing dataset.
# 5. Report values for preformance study metrics like accuracy, precision, recall, F1 Score.

# %%
##---------Type the code below this line------------------##

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# Plot Training and Validation Accuracy
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

# Plot Training and Validation Loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

plt.show()

# Report Testing Accuracy and Loss
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc:.4f}")
print(f"Test Loss: {test_loss:.4f}")

# Generate Predictions for Confusion Matrix
y_pred_probs = model.predict(X_test)
y_pred = (y_pred_probs > 0.5).astype(int)  # Convert probabilities to binary labels

# Compute Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=["Negative", "Positive"], yticklabels=["Negative", "Positive"])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Report Performance Metrics
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Test Accuracy: 0.8359
# Test Loss: 0.5634
# 776/776 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step
# Accuracy: 0.8359
# Precision: 0.8500
# Recall: 0.8170
# F1 Score: 0.8331

# %% [markdown]
# # 8. Model architecture - Score: 1 mark
#
#
# Modify the architecture designed in section 4.1
#
# 1. by decreasing one layer
# 2. by increasing one layer
#
# For example, if the architecture in 4.1 has 5 layers, then 8.1 should have 4 layers and 8.2 should have 6 layers.
#
# Plot the comparison of the training and validation accuracy of the three architecures (4.1, 8.1 and 8.2)

# %%
##---------Type the code below this line------------------##

histories = {"original": history}

# Model with One Less Layer
model_less = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# Model with One More Layer
model_more = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(256, activation='relu'),  # Added an extra layer
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

histories['model_less'] = train_model(model_less)
histories['model_more'] = train_model(model_more)

#
# Out:
# Model compiling
# Model training started
# Epoch 1/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.7267 - loss: 0.5777 - val_accuracy: 0.8156 - val_loss: 0.5269
# Epoch 2/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8269 - loss: 0.4260 - val_accuracy: 0.7265 - val_loss: 0.5306
# Epoch 3/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 20ms/step - accuracy: 0.8315 - loss: 0.3948 - val_accuracy: 0.8597 - val_loss: 0.4247
# Epoch 4/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.8754 - loss: 0.3051 - val_accuracy: 0.6537 - val_loss: 0.7887
# Epoch 5/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 23ms/step - accuracy: 0.8500 - loss: 0.3585 - val_accuracy: 0.6459 - val_loss: 0.8203
# Epoch 6/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.8770 - loss: 0.3208 - val_accuracy: 0.7966 - val_loss: 0.4201
# Epoch 7/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.8747 - loss: 0.3017 - val_accuracy: 0.5679 - val_loss: 1.2404
# Epoch 8/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.8949 - loss: 0.2625 - val_accuracy: 0.7496 - val_loss: 0.7103
# Epoch 9/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 15s 39ms/step - accuracy: 0.9025 - loss: 0.2508 - val_accuracy: 0.7963 - val_loss: 0.4717
# Epoch 10/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.9086 - loss: 0.2401 - val_accuracy: 0.7899 - val_loss: 0.4649
# Epoch 11/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 12s 31ms/step - accuracy: 0.8963 - loss: 0.2676 - val_accuracy: 0.8439 - val_loss: 0.4220
# Epoch 12/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 16s 20ms/step - accuracy: 0.9031 - loss: 0.2507 - val_accuracy: 0.6087 - val_loss: 1.0357
# Epoch 13/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9154 - loss: 0.2276 - val_accuracy: 0.7539 - val_loss: 0.5771
# Epoch 14/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9265 - loss: 0.1982 - val_accuracy: 0.6329 - val_loss: 1.9355
# Epoch 15/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9340 - loss: 0.1787 - val_accuracy: 0.8154 - val_loss: 0.4994
# Epoch 16/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.9356 - loss: 0.1778 - val_accuracy: 0.6913 - val_loss: 1.2114
# Epoch 17/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 23ms/step - accuracy: 0.9316 - loss: 0.1912 - val_accuracy: 0.8530 - val_loss: 0.3715
# Epoch 18/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9151 - loss: 0.2296 - val_accuracy: 0.6676 - val_loss: 1.4317
# Epoch 19/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9277 - loss: 0.1893 - val_accuracy: 0.6898 - val_loss: 1.9368
# Epoch 20/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9338 - loss: 0.1817 - val_accuracy: 0.5610 - val_loss: 5.6900
# Model compiling
# Model training started
# Epoch 1/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 46ms/step - accuracy: 0.7009 - loss: 0.5631 - val_accuracy: 0.7650 - val_loss: 0.4571
# Epoch 2/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 19s 42ms/step - accuracy: 0.8749 - loss: 0.3020 - val_accuracy: 0.6992 - val_loss: 0.6365
# Epoch 3/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 15s 40ms/step - accuracy: 0.9002 - loss: 0.2432 - val_accuracy: 0.7792 - val_loss: 0.4459
# Epoch 4/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 41ms/step - accuracy: 0.8994 - loss: 0.2468 - val_accuracy: 0.7550 - val_loss: 0.5242
# Epoch 5/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 40ms/step - accuracy: 0.9127 - loss: 0.2172 - val_accuracy: 0.7120 - val_loss: 0.8852
# Epoch 6/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 16s 40ms/step - accuracy: 0.9238 - loss: 0.1951 - val_accuracy: 0.6145 - val_loss: 1.4249
# Epoch 7/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 16s 41ms/step - accuracy: 0.9038 - loss: 0.2304 - val_accuracy: 0.7555 - val_loss: 0.5117
# Epoch 8/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 27s 58ms/step - accuracy: 0.9291 - loss: 0.1834 - val_accuracy: 0.7127 - val_loss: 0.7696
# Epoch 9/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 35s 41ms/step - accuracy: 0.9339 - loss: 0.1669 - val_accuracy: 0.7976 - val_loss: 0.5037
# Epoch 10/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.9448 - loss: 0.1472 - val_accuracy: 0.7596 - val_loss: 0.6644
# Epoch 11/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 36s 40ms/step - accuracy: 0.9400 - loss: 0.1527 - val_accuracy: 0.7578 - val_loss: 0.5357
# Epoch 12/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 40ms/step - accuracy: 0.9270 - loss: 0.1822 - val_accuracy: 0.7706 - val_loss: 0.6458
# Epoch 13/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.9432 - loss: 0.1490 - val_accuracy: 0.8116 - val_loss: 0.4499
# Epoch 14/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 53ms/step - accuracy: 0.9497 - loss: 0.1312 - val_accuracy: 0.8416 - val_loss: 0.4141
# Epoch 15/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 37s 43ms/step - accuracy: 0.9544 - loss: 0.1219 - val_accuracy: 0.8073 - val_loss: 0.5247
# Epoch 16/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 17s 42ms/step - accuracy: 0.9633 - loss: 0.0986 - val_accuracy: 0.7852 - val_loss: 0.5735
# Epoch 17/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 43ms/step - accuracy: 0.9546 - loss: 0.1194 - val_accuracy: 0.7131 - val_loss: 1.5336
# Epoch 18/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 17s 43ms/step - accuracy: 0.9631 - loss: 0.0988 - val_accuracy: 0.6696 - val_loss: 1.4633
# Epoch 19/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 18s 45ms/step - accuracy: 0.9346 - loss: 0.1716 - val_accuracy: 0.6209 - val_loss: 1.1139
# Epoch 20/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 19s 43ms/step - accuracy: 0.9662 - loss: 0.0965 - val_accuracy: 0.7759 - val_loss: 0.7065

# %%
def comparision_plot(histories):
  plt.figure(figsize=(12, 6))

  for name, history in histories.items():
      plt.plot(history.history['accuracy'], label=f"{name} Train", linestyle='--')
      plt.plot(history.history['val_accuracy'], label=f"{name} Validation")

  plt.xlabel('Epochs')
  plt.ylabel('Accuracy')
  plt.title('Training vs Validation Accuracy')
  plt.legend()
  plt.show()

comparision_plot(histories)

# %% [markdown]
# # 9. Regularisations - Score: 1 mark
#
# Modify the architecture designed in section 4.1
#
# 1. Dropout of ratio 0.25
# 2. Dropout of ratio 0.25 with L2 regulariser with factor 1e−04.
#
# Plot the comparison of the training and validation accuracy of the three (4.1, 9.1 and 9.2)

# %%
##---------Type the code below this line------------------##

# 1. Dropout of ratio 0.25
model_dropout_25 = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),  # Dropout layer with 25% dropout
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),  # Another dropout layer
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# 2. Dropout of ratio 0.25 with L2 regulariser with factor 1e−04.
from tensorflow.keras.regularizers import l2
model_dropout_l2_small = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=l2(1e-4)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),  # Dropout with 25%
    tf.keras.layers.Dense(64, activation='relu', kernel_regularizer=l2(1e-4)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.25),  # Dropout with 25%
    tf.keras.layers.Dense(1, activation='sigmoid')
])
histories = {"original": history}
histories['model_dropout_25'] = train_model(model_dropout_25)
histories['model_dropout_l2_small'] = train_model(model_dropout_l2_small)
# Out:
# Model compiling
# Model training started
# Epoch 1/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 12s 26ms/step - accuracy: 0.6266 - loss: 0.6792 - val_accuracy: 0.7765 - val_loss: 0.5272
# Epoch 2/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.7870 - loss: 0.4528 - val_accuracy: 0.7253 - val_loss: 0.5249
# Epoch 3/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.8302 - loss: 0.3831 - val_accuracy: 0.8257 - val_loss: 0.3731
# Epoch 4/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.8479 - loss: 0.3466 - val_accuracy: 0.8270 - val_loss: 0.3846
# Epoch 5/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 12s 30ms/step - accuracy: 0.8501 - loss: 0.3357 - val_accuracy: 0.5343 - val_loss: 2.0177
# Epoch 6/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.8599 - loss: 0.3195 - val_accuracy: 0.7915 - val_loss: 0.4306
# Epoch 7/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.8841 - loss: 0.2793 - val_accuracy: 0.8552 - val_loss: 0.3372
# Epoch 8/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.8859 - loss: 0.2691 - val_accuracy: 0.8271 - val_loss: 0.3739
# Epoch 9/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.8972 - loss: 0.2450 - val_accuracy: 0.8488 - val_loss: 0.3612
# Epoch 10/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.8624 - loss: 0.3097 - val_accuracy: 0.8495 - val_loss: 0.3531
# Epoch 11/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 26ms/step - accuracy: 0.8965 - loss: 0.2434 - val_accuracy: 0.6612 - val_loss: 0.9592
# Epoch 12/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.8886 - loss: 0.2631 - val_accuracy: 0.7049 - val_loss: 0.5303
# Epoch 13/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 12s 28ms/step - accuracy: 0.8767 - loss: 0.2766 - val_accuracy: 0.7906 - val_loss: 0.4116
# Epoch 14/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.9059 - loss: 0.2211 - val_accuracy: 0.8079 - val_loss: 0.4407
# Epoch 15/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9050 - loss: 0.2287 - val_accuracy: 0.7665 - val_loss: 0.4767
# Epoch 16/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.8751 - loss: 0.2817 - val_accuracy: 0.8579 - val_loss: 0.3436
# Epoch 17/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 13s 30ms/step - accuracy: 0.9132 - loss: 0.2137 - val_accuracy: 0.8135 - val_loss: 0.4518
# Epoch 18/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 28ms/step - accuracy: 0.9241 - loss: 0.1861 - val_accuracy: 0.8613 - val_loss: 0.3338
# Epoch 19/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9243 - loss: 0.1842 - val_accuracy: 0.6649 - val_loss: 1.2997
# Epoch 20/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9064 - loss: 0.2201 - val_accuracy: 0.7969 - val_loss: 0.4362
# Model compiling
# Model training started
# Epoch 1/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 16s 37ms/step - accuracy: 0.6282 - loss: 0.6985 - val_accuracy: 0.7721 - val_loss: 0.6069
# Epoch 2/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.7476 - loss: 0.5500 - val_accuracy: 0.6701 - val_loss: 0.5763
# Epoch 3/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 23s 35ms/step - accuracy: 0.8321 - loss: 0.4145 - val_accuracy: 0.8590 - val_loss: 0.4279
# Epoch 4/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8455 - loss: 0.3916 - val_accuracy: 0.6068 - val_loss: 1.2577
# Epoch 5/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.8382 - loss: 0.3910 - val_accuracy: 0.6880 - val_loss: 0.6895
# Epoch 6/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 26s 43ms/step - accuracy: 0.8254 - loss: 0.4172 - val_accuracy: 0.8443 - val_loss: 0.3949
# Epoch 7/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 16s 32ms/step - accuracy: 0.8680 - loss: 0.3391 - val_accuracy: 0.8071 - val_loss: 0.4469
# Epoch 8/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.8963 - loss: 0.2898 - val_accuracy: 0.8021 - val_loss: 0.4659
# Epoch 9/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 13s 32ms/step - accuracy: 0.8689 - loss: 0.3391 - val_accuracy: 0.7916 - val_loss: 0.4517
# Epoch 10/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 14s 35ms/step - accuracy: 0.8912 - loss: 0.2986 - val_accuracy: 0.7390 - val_loss: 0.5242
# Epoch 11/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 18s 29ms/step - accuracy: 0.8792 - loss: 0.3231 - val_accuracy: 0.8022 - val_loss: 0.4568
# Epoch 12/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.9201 - loss: 0.2418 - val_accuracy: 0.8467 - val_loss: 0.3989
# Epoch 13/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.9164 - loss: 0.2535 - val_accuracy: 0.6821 - val_loss: 0.5831
# Epoch 14/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 20s 29ms/step - accuracy: 0.9196 - loss: 0.2427 - val_accuracy: 0.7506 - val_loss: 0.5955
# Epoch 15/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.9210 - loss: 0.2366 - val_accuracy: 0.7870 - val_loss: 0.5380
# Epoch 16/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 10s 27ms/step - accuracy: 0.9209 - loss: 0.2356 - val_accuracy: 0.6898 - val_loss: 1.1827
# Epoch 17/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 24s 35ms/step - accuracy: 0.9220 - loss: 0.2419 - val_accuracy: 0.8050 - val_loss: 0.4976
# Epoch 18/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 11s 29ms/step - accuracy: 0.8922 - loss: 0.2941 - val_accuracy: 0.8550 - val_loss: 0.3858
# Epoch 19/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.9020 - loss: 0.2755 - val_accuracy: 0.7149 - val_loss: 1.0039
# Epoch 20/20
# 390/390 ━━━━━━━━━━━━━━━━━━━━ 21s 29ms/step - accuracy: 0.9109 - loss: 0.2534 - val_accuracy: 0.8105 - val_loss: 0.4463

# %%
comparision_plot(histories)

# %% [markdown]
# # 10. Optimisers -Score: 1 mark
#
# Modify the code written in section 5.2
#
# 1. RMSProp with your choice of hyper parameters
# 2. Adam with your choice of hyper parameters
#
# Plot the comparison of the training and validation accuracy of the three (5.2, 10.1 and 10.2)

# %%
##---------Type the code below this line------------------##

# %% [markdown]
# # 11. Conclusion - Score: 1 mark
#
# Comparing the sections 4.1, 5.2, 8, 9, and 10, present your observations on which model or architecture or regualiser or optimiser perfomed better.

# %%
##---------Type the code below this line------------------##

# %% [markdown]
# ### NOTE
#
#
# All Late Submissions will incur a <b>penalty of -2 marks </b>. So submit your assignments on time.
#
# Good Luck
